# %% [markdown]
# ## Part 1: Pulse Rate Algorithm
#
# ### Contents
# Fill out this notebook as part of your final project submission.
#
# **You will have to complete both the Code and Project Write-up sections.**
# - The [Code](#Code) is where you will write a **pulse rate algorithm** and already includes the starter code.
#    - Imports - These are the imports needed for Part 1 of the final project.
#      - [glob](https://docs.python.org/3/library/glob.html)
#      - [numpy](https://numpy.org/)
#      - [scipy](https://www.scipy.org/)
# - The [Project Write-up](#Project-Write-up) to describe why you wrote the algorithm for the specific case.
#
#
# ### Dataset
# You will be using the **Troika**[1] dataset to build your algorithm. Find the dataset under `datasets/troika/training_data`. The `README` in that folder will tell you how to interpret the data. The starter code contains a function to help load these files.
#
# 1. Zhilin Zhang, Zhouyue Pi, Benyuan Liu, ‘‘TROIKA: A General Framework for Heart Rate Monitoring Using Wrist-Type Photoplethysmographic Signals During Intensive Physical Exercise,’’IEEE Trans. on Biomedical Engineering, vol. 62, no. 2, pp. 522-531, February 2015. Link
#
# -----

# %% [markdown]
# ### Code

# %%
import glob
import sys
import numpy as np
import scipy as sp
import scipy.io
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from matplotlib import mlab
import matplotlib.gridspec as gridspec
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import pandas as pd


def LoadTroikaDataset():
    """
    Retrieve the .mat filenames for the troika dataset.

    Review the README in ./datasets/troika/ to understand the organization of the .mat files.

    Returns:
        data_fls: Names of the .mat files that contain signal data
        ref_fls: Names of the .mat files that contain reference data
        <data_fls> and <ref_fls> are ordered correspondingly, so that ref_fls[5] is the 
            reference data for data_fls[5], etc...
    """
    data_dir = "./datasets/troika/training_data"
    data_fls = sorted(glob.glob(data_dir + "/DATA_*.mat"))
    ref_fls = sorted(glob.glob(data_dir + "/REF_*.mat"))
    return data_fls, ref_fls

def LoadTroikaDataFile(data_fl):
    """
    Loads and extracts signals from a troika data file.

    Usage:
        data_fls, ref_fls = LoadTroikaDataset()
        ppg, accx, accy, accz = LoadTroikaDataFile(data_fls[0])

    Args:
        data_fl: (str) filepath to a troika .mat file.

    Returns:
        numpy arrays for ppg, accx, accy, accz signals.
    """
    data = sp.io.loadmat(data_fl)['sig']
    ### return the since the third row
    return data[2:]

def AggregateErrorMetric(pr_errors, confidence_est):
    """
    Computes an aggregate error metric based on confidence estimates.

    Computes the MAE at 90% availability. 

    Args:
        pr_errors: a numpy array of errors between pulse rate estimates and corresponding 
            reference heart rates.
        confidence_est: a numpy array of confidence estimates for each pulse rate
            error.

    Returns:
        the MAE at 90% availability
    """
    # Higher confidence means a better estimate. The best 90% of the estimates
    #    are above the 10th percentile confidence.
    percentile90_confidence = np.percentile(confidence_est, 10)

    # Find the errors of the best pulse rate estimates
    best_estimates = pr_errors[confidence_est >= percentile90_confidence]

    # Return the mean absolute error
    return np.mean(np.abs(best_estimates))


def create_features(indice, ppg, accx, accy, accz, min_freq_v, max_freq_v, fs=125, verbose=False, plot_frequency_ppg = False, plot_frequency_acc = False):
    """
    Apply Troika process to the pppg and accelerometer signals in order to extract feature for our trained dataset.
    
    
    :param indice: index of the iteration realted to the windows time.
    :param ppg: slice PPG signal.
    :type ppg: ndarray
    :param accx: accelerometer signal on the x-axis
    :type accx: ndarray
    :param accy: accelerometer signal on the y-axis
    :type accy: ndarray
    :param accz: accelerometer signal on the z-axis
    :type accz: ndarray
    :param min_freq_v: min frequency allowed in our descompose signal.
    :type min_freq_v: float
    :param max_freq_v: max frequency allowed in our descompose signal.
    :type max_freq_v: float
    :param fs:  sampling rate
    :type  fs: integer
    :param verbose: show the value of ground truth for the slice window.
    :type verbose: bool
    :param plot_frequency_ppg: plot the frequency domain of the ppg signal for the segment of the signal.
    :type  plot_frequency_ppg: bool
    :param plot_frequency_acc: plot the frequency domain of the acc signal for the segment of the signal.
    :type  plot_frequency_acc: bool
    """
    
    #############################################################################
    #### First Band pass Filtering all the signal PPG, and acceleration 
    ##  Use the 40-240BPM range to create your pass band.
    #############################################################################
    ppg = bandpass_filter(ppg, min_freq = min_freq_v, max_freq = max_freq_v)
    accx = bandpass_filter(accx, min_freq = min_freq_v, max_freq = max_freq_v)
    accy = bandpass_filter(accy, min_freq = min_freq_v, max_freq = max_freq_v)
    accz = bandpass_filter(accz, min_freq = min_freq_v, max_freq = max_freq_v)
    
    # Aggregate accelerometer data into single signal
    accy_mean = accy - np.mean(accy) # Center Y values
    acc_mag_unfiltered = np.sqrt(accx**2 + accy_mean**2 + accz**2)
    acc_mag = bandpass_filter(acc_mag_unfiltered, min_freq = min_freq_v, max_freq = max_freq_v)
  
    #############################################################################
    #### Signal Decomposition ##################################################
    #############################################################################
    fft_len = len(ppg)*4
    
    fft_ppg_initial = np.fft.rfft(ppg)
    freqs_original = np.fft.rfftfreq(len(ppg), 1 / fs)
  
    fft_acc_original = np.fft.rfft(acc_mag)
    freqs_acc_original = np.fft.rfftfreq(len(acc_mag), 1 / fs)
    
    freqs_initial = np.fft.rfftfreq(fft_len, 1 / fs)
    low_freqs = (freqs_initial >= (min_freq_v)) & (freqs_initial <= (max_freq_v))
    
    ### get magnitude
    mag_freq_ppg, fft_ppg = fourier_transform(ppg, freqs_initial, low_freqs, fft_len)
    mag_freq_acc, fft_acc = fourier_transform(acc_mag, freqs_initial, low_freqs, fft_len)    
    
    #############################################################################
    ### Find Peaks ##########################################################
    peaks_ppg = find_peaks(mag_freq_ppg, height=30, distance=1)[0]
    peaks_acc = find_peaks(mag_freq_acc, height=30, distance=1)[0]
    #############################################################################
     
    if plot_frequency_ppg:
        if indice < 2:
            gs = gridspec.GridSpec(2, 2)
            plt.figure()
            ax = plt.subplot(gs[0, 0])
            ax.set_title(f'Initial Frequency PPG {indice}')
            ax.plot(freqs_original, fft_ppg_initial)
            ax.set_xlabel('Frequency (Hz)')
        
            ax = plt.subplot(gs[0, 1])
            ax.set_title(f'Low Frequency PPG {indice}')
            ax.plot(freqs_initial[low_freqs], mag_freq_ppg)
            ax.set_xlabel('Frequency (Hz)')   
            
            
            ### Peaks plot            
            ax = plt.subplot(gs[1, :])
            ax.set_title(f'Find Peaks {indice}')
            ax.plot(mag_freq_ppg)
            ax.plot(peaks_ppg, mag_freq_ppg[peaks_ppg], '+r', ms = 10)
            ax.set_xlabel('Time')              
            plt.show()      
    
    
    if plot_frequency_acc:
        if indice < 2:
            gs = gridspec.GridSpec(2, 2)
            plt.figure()
            ax = plt.subplot(gs[0, 0])
            ax.set_title(f'Initial Frequency ACC {indice}')
            ax.plot(freqs_acc_original, fft_acc_original)
            ax.set_xlabel('Frequency (Hz)')
        
            ax = plt.subplot(gs[0, 1])
            ax.set_title(f'Low Frequency ACC {indice}')
            ax.plot(freqs_acc_original[low_freqs], mag_freq_acc)
            ax.set_xlabel('Frequency (Hz)')   
            
            
            ### Peaks plot            
            ax = plt.subplot(gs[1, :])
            ax.set_title(f'Find Peaks ACC {indice}')
            ax.plot(mag_freq_ppg)
            ax.plot(peaks_acc, mag_freq_acc[peaks_acc], 'xg', ms = 10)
            ax.set_xlabel('Time')              
            
            plt.show()       
    
    
    ppg_feature = freqs_original[np.argmax(fft_ppg_initial)]
    acc_feature = freqs_acc_original[np.argmax(fft_acc_original)]
    

    return (np.array([ppg_feature, acc_feature, len(peaks_ppg), len(peaks_acc)])), freqs_initial,  fft_ppg
                

        
def Confidence(estimation, freqs_initial, fft_ppg, min_freq_v):        
    """
    Calculate the confidence base on the summing of the frequency spectrum around the estimation of the heart rate 
    and dividing it by the sum of the entire spectrum.
    
    
    :param estimation: heart rate estimation
    :type estimation: float
    
    :param freqs_initial: the Discrete Fourier Transform sample frequencies
    :type freqs_initial: ndarray
    
    :param fft_ppg: Compute fourier transformation
    :type fft_ppg: ndarray
    
    :param min_freq_v: min frequency allowed in our descompose signal.
    :type min_freq_v: float
    
    :return: confidence value
    :rtype: float
    """
    #############################################################################
    #### Confidence ############################################################
    #############################################################################
    chosen_freq = estimation / 60.0
    
    win_freqs = (freqs_initial >= chosen_freq - min_freq_v) & (freqs_initial <= chosen_freq + min_freq_v)
    abs_fft_ppg = np.abs(fft_ppg)

    # Sum frequency spectrum near pulse rate estimate and divide by sum of entire spectrum
    confidence = np.sum(abs_fft_ppg[win_freqs])/np.sum(abs_fft_ppg)

    return (estimation, confidence)


def fourier_transform(x, freqs, low_freqs, fft_len):
    ''' Compute and return FFT and magnitude of FFT for given low frequencies
 
    :param x: input signal to transform
    :type x: ndarray
    :param freqs: full list of FFT frequency bins.
    :type freqs: integer ndarray
    :param low_freqs: low frequency bins between 40 BPM and 240 BPM
    :type low_freqs: boolean ndarray
    :param fft_len: length of FFT to compute
    :type fft_len: integer  
    :return:
    mag_freq_x: magnitude of lower frequencies of the FFT transformed signal
    fft_x: FFT of normalized input signal
    '''
    # Take an FFT of the mean normalized signal
    norm_x = (x - np.mean(x))/(max(x)-min(x))
    fft_x = np.fft.rfft(norm_x, fft_len)

    # Calculate magnitude of the lower frequencies
    mag_freq_x = np.abs(fft_x)[low_freqs]
    return mag_freq_x, fft_x


def bandpass_filter(signal, fs = 125, min_freq = 40/60.0, max_freq = 240/60.0):
    """
    Filter the signal between the min_freq and max_freq
    
    
    :param signal: signal from PPG or Accelerometer
    :type signal: ndarray
    
    :param fs: sampling rate
    :type fs: integer
    
    :param min_freq:  min frequency allowed in our descompose signal.
    :type min_freq: float
    
    :param max_freq:  max frequency allowed in our descompose signal.
    :type max_freq: float
    
    :return:  band pass signal
    :rtype: ndarray
    """
    
    pass_band = (min_freq, max_freq)
    b, a = scipy.signal.butter(3, pass_band, btype = 'bandpass', fs=fs)
    return scipy.signal.filtfilt(b, a, signal)


def TrainModel():
    """
    Train the model base on features extracted from our PPG and accelerometer signal.
    :return: Model trained over 80% sample of the dataset.
    """
    data_fls, ref_fls = LoadTroikaDataset()

    features_list, target_list = [], []
    
    for data_fl, ref_fl in zip(data_fls, ref_fls):    
        # Load data using LoadTroikaDataFile
        ppg, accx, accy, accz = LoadTroikaDataFile(data_fl)
        Fs = 125 # Troika data has sampling rate of 125 Hz
        # Compute pulse rate estimates and estimation confidence.

        min_freq_val = 40/60.0
        max_freq_val = 240/60.0    

        #######################################
        ######################################
        # Load data using LoadTroikaDataFile
        window_size = 8*Fs # Ground truth BPM provided in 8 second windows
        window_shift = 2*Fs # Successive ground truth windows overlap by 2 seconds

        reference = sp.io.loadmat(ref_fl)

        errs = []
        confs = []

        # For each 8 second window, compute a predicted BPM and confidence and compare to ground truth
        offset = 0
        
        for indice, eval_window_idx in enumerate(range(len(reference['BPM0']))):
            window_start = offset
            window_end = window_size + offset
            offset += window_shift

            ppg_window = ppg[window_start:window_end]
            accx_window = accx[window_start:window_end]
            accy_window = accy[window_start:window_end]
            accz_window = accz[window_start:window_end]
            groundTruthBPM = reference['BPM0'][eval_window_idx][0]

            feature, _ , _ = create_features(indice, ppg_window, accx_window, accy_window, accz_window, 
                                        min_freq_val, max_freq_val, Fs, verbose = False, 
                                        plot_frequency_ppg = False, plot_frequency_acc = False)            

            features_list.append(feature)
            target_list.append(groundTruthBPM)

    features = np.array(features_list)
    target =  np.array(target_list)
    
    dffeatures = pd.DataFrame(features)
    
    model_rf = RandomForestRegressor(n_estimators = 350, max_depth = 15)
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 2021)
    
    model_rf.fit(X_train, y_train)
    return model_rf    


def Evaluate():
    """
    Top-level function evaluation function.

    Runs the pulse rate algorithm on the Troika dataset and returns an aggregate error metric.

    :return: Pulse rate error on the Troika dataset. See AggregateErrorMetric.
    :rtype: 
    """
    ## Trained Model
    global model_ml
    model_ml = TrainModel()
    
    
    ### Test Algorithm
    # Retrieve dataset files
    data_fls, ref_fls = LoadTroikaDataset()
    errs, confs = [], []
    
    
    for data_fl, ref_fl in zip(data_fls, ref_fls):
        # Run the pulse rate algorithm on each trial in the dataset
        errors, confidence = RunPulseRateAlgorithm(data_fl, ref_fl)
        errs.append(errors)
        confs.append(confidence)
        # Compute aggregate error metric
        
    errs = np.hstack(errs)
    confs = np.hstack(confs)
    return AggregateErrorMetric(errs, confs)

def RunPulseRateAlgorithm(data_fl, ref_fl):
    """
    Get the heart rate estimation and the confidence values for an specific data file.
    
    :param data_fl: path data of the subjects
    :param ref_fl: path data of the grounth truth
    
    
    """
    # Load data using LoadTroikaDataFile
    ppg, accx, accy, accz = LoadTroikaDataFile(data_fl)
    Fs = 125 # Troika data has sampling rate of 125 Hz
    # Compute pulse rate estimates and estimation confidence.
    
    min_freq_val = 40/60.0
    max_freq_val = 240/60.0
    
    #######################################
    ######################################
    # Load data using LoadTroikaDataFile
    window_size = 8*Fs # Ground truth BPM provided in 8 second windows
    window_shift = 2*Fs # Successive ground truth windows overlap by 2 seconds
    
    reference = sp.io.loadmat(ref_fl)

    errs = []
    confs = []
    
    # For each 8 second window, compute a predicted BPM and confidence and compare to ground truth
    offset = 0
    
    
    for indice, eval_window_idx in enumerate(range(len(reference['BPM0']))):
        # Set verbose to True to visualize plot analysis
        verbose = True
        # verbose = True if eval_window_idx == 28 else False
    
        window_start = offset
        window_end = window_size+offset
        offset += window_shift
        
        if verbose:
            print(f"Win start,end: {window_start}, {window_end}")

        ppg_window = ppg[window_start:window_end]
        accx_window = accx[window_start:window_end]
        accy_window = accy[window_start:window_end]
        accz_window = accz[window_start:window_end]
        
        groundTruthBPM = reference['BPM0'][eval_window_idx][0]
    
        feature, freqs_initial,  fft_ppg  = create_features(indice, ppg_window, accx_window, accy_window, accz_window, 
                                    min_freq_val, max_freq_val, Fs, verbose = verbose, 
                                    plot_frequency_ppg = False, plot_frequency_acc = False)
        
        
        estimation_hr =  model_ml.predict(np.reshape(feature, (1, -1)))[0]
        
        if verbose:
            print(f'Ground Truth BPM: {groundTruthBPM}')
            print(f'Prediction BPM {estimation_hr}')

            
        estimation_hr, conf = Confidence(estimation_hr, freqs_initial, fft_ppg, min_freq_val)    
        predError = groundTruthBPM - estimation_hr
        errs.append(predError)
        confs.append(conf)    
    
    
    # Return per-estimate mean absolute error and confidence as a 2-tuple of numpy arrays.
    errors, confidence = np.array(errs), np.array(confs)  # Dummy placeholders. Remove
    return errors, confidence

# %%
import scipy.signal
sth = Evaluate()
# Out:
# Win start,end: 0, 1000
# Ground Truth BPM: 74.33920704845815
# Prediction BPM 90.03269772358979
# Win start,end: 250, 1250
# Ground Truth BPM: 76.35746606334841
# Prediction BPM 95.7958997802082
# Win start,end: 500, 1500
# Ground Truth BPM: 77.14285714285714
# Prediction BPM 94.26507233370029
# Win start,end: 750, 1750
# Ground Truth BPM: 74.66814159292035
# Prediction BPM 97.48102778071645
# Win start,end: 1000, 2000
# Ground Truth BPM: 72.58064516129032
# Prediction BPM 81.37918328726016
# Win start,end: 1250, 2250
# Ground Truth BPM: 71.68458781362007
# Prediction BPM 88.8749572158421
# Win start,end: 1500, 2500
# Ground Truth BPM: 72.89416846652267
# Prediction BPM 115.0685556419423
# Win start,end: 1750, 2750
# Ground Truth BPM: 73.449401523395
# Prediction BPM 96.70456130418694
# Win start,end: 2000, 3000
# Ground Truth BPM: 75.33482142857142
# Prediction BPM 127.0361410593432
# Win start,end: 2250, 3250
# Ground Truth BPM: 76.84426229508196
# Prediction BPM 144.54905122510942
# Win start,end: 2500, 3500
# Ground Truth BPM: 79.59905660377359
# Prediction BPM 85.8985754773486
# Win start,end: 2750, 3750
# Ground Truth BPM: 79.11392405063292
# Prediction BPM 89.92534202660998
# Win start,end: 3000, 4000
# Ground Truth BPM: 74.50331125827813
# Prediction BPM 101.70150174243328
# Win start,end: 3250, 4250
# Ground Truth BPM: 70.83825265643448
# Prediction BPM 100.33782430250665
# Win start,end: 3500, 4500
# Ground Truth BPM: 69.58762886597938
# Prediction BPM 84.76646403231996
# Win start,end: 3750, 4750
# Ground Truth BPM: 71.94244604316548
# Prediction BPM 95.36271556715644
# Win start,end: 4000, 5000
# Ground Truth BPM: 77.31958762886597
# Prediction BPM 86.86650944841571
# Win start,end: 4250, 5250
# Ground Truth BPM: 80.29978586723769
# Prediction BPM 95.52024138936753
# Win start,end: 4500, 5500
# Ground Truth BPM: 82.87292817679558
# Prediction BPM 86.93222644848836
# Win start,end: 4750, 5750
# Ground Truth BPM: 83.51893095768374
# Prediction BPM 92.70926154678767
# Win start,end: 5000, 6000
# Ground Truth BPM: 84.65011286681715
# Prediction BPM 104.75067119612179
# Win start,end: 5250, 6250
# Ground Truth BPM: 88.23529411764706
# Prediction BPM 126.75429540015804
# Win start,end: 5500, 6500
# Ground Truth BPM: 90.95920617420066
# Prediction BPM 151.66066187204277
# Win start,end: 5750, 6750
# Ground Truth BPM: 92.87925696594428
# Prediction BPM 107.84418249543654
# Win start,end: 6000, 7000
# Ground Truth BPM: 94.73684210526316
# Prediction BPM 123.01808098007464
# Win start,end: 6250, 7250
# Ground Truth BPM: 97.2877358490566
# Prediction BPM 155.65600317853247
# Win start,end: 6500, 7500
# Ground Truth BPM: 99.66777408637873
# Prediction BPM 145.3037753800799
# Win start,end: 6750, 7750
# Ground Truth BPM: 101.58013544018058
# Prediction BPM 134.53829056766853
# Win start,end: 7000, 8000
# Ground Truth BPM: 102.84810126582279
# Prediction BPM 128.52035503874558
# Win start,end: 7250, 8250
# Ground Truth BPM: 103.44827586206898
# Prediction BPM 113.52186787886481
# Win start,end: 7500, 8500
# Ground Truth BPM: 103.17460317460318
# Prediction BPM 111.5024162627821
# Win start,end: 7750, 8750
# Ground Truth BPM: 102.95670538542767
# Prediction BPM 113.98916961134869
# Win start,end: 8000, 9000
# Ground Truth BPM: 103.28389830508476
# Prediction BPM 107.991260203877
# Win start,end: 8250, 9250
# Ground Truth BPM: 104.05549626467447
# Prediction BPM 109.72658425204366
# Win start,end: 8500, 9500
# Ground Truth BPM: 106.20915032679738
# Prediction BPM 104.0953869987802
# Win start,end: 8750, 9750
# Ground Truth BPM: 108.58324715615306
# Prediction BPM 140.962161013982
# Win start,end: 9000, 10000
# Ground Truth BPM: 110.66969353007946
# Prediction BPM 125.69498897272993
# Win start,end: 9250, 10250
# Ground Truth BPM: 111.58342189160469
# Prediction BPM 115.77495923236134
# Win start,end: 9500, 10500
# Ground Truth BPM: 112.29946524064171
# Prediction BPM 119.23960175408975
# Win start,end: 9750, 10750
# Ground Truth BPM: 112.78195488721803
# Prediction BPM 119.42336417970442
# Win start,end: 10000, 11000
# Ground Truth BPM: 113.63636363636364
# Prediction BPM 130.14945188995304
# Win start,end: 10250, 11250
# Ground Truth BPM: 114.50381679389312
# Prediction BPM 122.08085241965792
# Win start,end: 10500, 11500
# Ground Truth BPM: 115.13157894736841
# Prediction BPM 129.08790592882747
# Win start,end: 10750, 11750
# Ground Truth BPM: 116.02209944751382
# Prediction BPM 124.16350485940723
# Win start,end: 11000, 12000
# Ground Truth BPM: 117.05685618729098
# Prediction BPM 139.6380479928082
# Win start,end: 11250, 12250
# Ground Truth BPM: 118.54583772391992
# Prediction BPM 110.69710230316987
# Win start,end: 11500, 12500
# Ground Truth BPM: 120.1923076923077
# Prediction BPM 117.75892818840599
# Win start,end: 11750, 12750
# Ground Truth BPM: 121.8851570964247
# Prediction BPM 134.31063738627498
# Win start,end: 12000, 13000
# Ground Truth BPM: 123.96694214876034
# Prediction BPM 128.98246807301405
# Win start,end: 12250, 13250
# Ground Truth BPM: 125.78616352201259
# Prediction BPM 132.76677474919575
# Win start,end: 12500, 13500
# Ground Truth BPM: 128.06830309498397
# Prediction BPM 125.96362781626041
# Win start,end: 12750, 13750
# Ground Truth BPM: 130.86150490730643
# Prediction BPM 121.72941467353711
# Win start,end: 13000, 14000
# Ground Truth BPM: 133.18534961154273
# Prediction BPM 141.3175308434493
# Win start,end: 13250, 14250
# Ground Truth BPM: 135.4941551540914
# Prediction BPM 131.07910355105173
# Win start,end: 13500, 14500
# Ground Truth BPM: 137.1951219512195
# Prediction BPM 136.7519140128296
# Win start,end: 13750, 14750
# Ground Truth BPM: 138.88888888888889
# Prediction BPM 131.32752984526937
# Win start,end: 14000, 15000
# Ground Truth BPM: 140.57331863285555
# Prediction BPM 136.37395543120383
# Win start,end: 14250, 15250
# Ground Truth BPM: 141.6579223504722
# Prediction BPM 149.83379406932679
# Win start,end: 14500, 15500
# Ground Truth BPM: 142.7061310782241
# Prediction BPM 135.18824988786514
# Win start,end: 14750, 15750
# Ground Truth BPM: 143.0084745762712
# Prediction BPM 142.62871043446685
# Win start,end: 15000, 16000
# Ground Truth BPM: 143.31210191082803
# Prediction BPM 142.99070548627077
# Win start,end: 15250, 16250
# Ground Truth BPM: 143.46439957492032
# Prediction BPM 144.3557343390991
# Win start,end: 15500, 16500
# Ground Truth BPM: 143.7699680511182
# Prediction BPM 143.33463664402598
# Win start,end: 15750, 16750
# Ground Truth BPM: 144.23076923076923
# Prediction BPM 143.0500010416187
# Win start,end: 16000, 17000
# Ground Truth BPM: 144.8170731707317
# Prediction BPM 147.79245869736468
# Win start,end: 16250, 17250
# Ground Truth BPM: 145.70552147239263
# Prediction BPM 149.08719772524861
# Win start,end: 16500, 17500
# Ground Truth BPM: 146.90721649484536
# Prediction BPM 153.44036761789724
# Win start,end: 16750, 17750
# Ground Truth BPM: 148.28303850156087
# Prediction BPM 154.893514148377
# Win start,end: 17000, 18000
# Ground Truth BPM: 149.8422712933754
# Prediction BPM 150.71991722943682
# Win start,end: 17250, 18250
# Ground Truth BPM: 151.2738853503185
# Prediction BPM 155.89529689354686
# Win start,end: 17500, 18500
# Ground Truth BPM: 152.40641711229947
# Prediction BPM 155.13055661147536
# Win start,end: 17750, 18750
# Ground Truth BPM: 153.72168284789643
# Prediction BPM 155.65600317853247
# Win start,end: 18000, 19000
# Ground Truth BPM: 154.72312703583063
# Prediction BPM 157.04385127823508
# Win start,end: 18250, 19250
# Ground Truth BPM: 155.22875816993462
# Prediction BPM 155.1673911188989
# Win start,end: 18500, 19500
# Ground Truth BPM: 155.44041450777203
# Prediction BPM 157.04385127823508
# Win start,end: 18750, 19750
# Ground Truth BPM: 155.27950310559007
# Prediction BPM 151.5865102168883
# Win start,end: 19000, 20000
# Ground Truth BPM: 154.95867768595042
# Prediction BPM 155.1673911188989
# Win start,end: 19250, 20250
# Ground Truth BPM: 154.72312703583063
# Prediction BPM 152.69458699432226
# Win start,end: 19500, 20500
# Ground Truth BPM: 154.55531453362255
# Prediction BPM 155.65600317853247
# Win start,end: 19750, 20750
# Ground Truth BPM: 155.1189245087901
# Prediction BPM 144.8810380489533
# Win start,end: 20000, 21000
# Ground Truth BPM: 155.1189245087901
# Prediction BPM 148.15189698079956
# Win start,end: 20250, 21250
# Ground Truth BPM: 155.1189245087901
# Prediction BPM 155.7395791949973
# Win start,end: 20500, 21500
# Ground Truth BPM: 154.95867768595042
# Prediction BPM 154.893514148377
# Win start,end: 20750, 21750
# Ground Truth BPM: 154.2207792207792
# Prediction BPM 138.55455866164456
# Win start,end: 21000, 22000
# Ground Truth BPM: 153.8876889848812
# Prediction BPM 137.80837939535786
# Win start,end: 21250, 22250
# Ground Truth BPM: 153.72168284789643
# Prediction BPM 149.84791965497345
# Win start,end: 21500, 22500
# Ground Truth BPM: 152.8969957081545
# Prediction BPM 152.00894627404784
# Win start,end: 21750, 22750
# Ground Truth BPM: 152.73311897106106
# Prediction BPM 150.7765090502604
# Win start,end: 22000, 23000
# Ground Truth BPM: 152.12981744421907
# Prediction BPM 149.81663778726255
# Win start,end: 22250, 23250
# Ground Truth BPM: 151.51515151515153
# Prediction BPM 107.51840373304498
# Win start,end: 22500, 23500
# Ground Truth BPM: 151.51515151515153
# Prediction BPM 161.03732825141952
# Win start,end: 22750, 23750
# Ground Truth BPM: 151.59574468085106
# Prediction BPM 143.15410358620804
# Win start,end: 23000, 24000
# Ground Truth BPM: 151.91897654584224
# Prediction BPM 136.4553895498835
# Win start,end: 23250, 24250
# Ground Truth BPM: 152.08110992529348
# Prediction BPM 144.284851851141
# Win start,end: 23500, 24500
# Ground Truth BPM: 151.91897654584224
# Prediction BPM 136.4553895498835
# Win start,end: 23750, 24750
# Ground Truth BPM: 151.75718849840257
# Prediction BPM 138.98184319460677
# Win start,end: 24000, 25000
# Ground Truth BPM: 151.59574468085106
# Prediction BPM 155.7395791949973
# Win start,end: 24250, 25250
# Ground Truth BPM: 151.4346439957492
# Prediction BPM 148.15189698079956
# Win start,end: 24500, 25500
# Ground Truth BPM: 151.75718849840257
# Prediction BPM 155.7395791949973
# Win start,end: 24750, 25750
# Ground Truth BPM: 151.59574468085106
# Prediction BPM 154.51387398045694
# Win start,end: 25000, 26000
# Ground Truth BPM: 151.59574468085106
# Prediction BPM 142.1090972907392
# Win start,end: 25250, 26250
# Ground Truth BPM: 151.4346439957492
# Prediction BPM 146.04278957393797
# Win start,end: 25500, 26500
# Ground Truth BPM: 150.95338983050848
# Prediction BPM 144.36455185044224
# Win start,end: 25750, 26750
# Ground Truth BPM: 150.95338983050848
# Prediction BPM 101.39205781942232
# Win start,end: 26000, 27000
# Ground Truth BPM: 150.79365079365078
# Prediction BPM 135.08956985999706
# Win start,end: 26250, 27250
# Ground Truth BPM: 150.31645569620255
# Prediction BPM 147.88751398591373
# Win start,end: 26500, 27500
# Ground Truth BPM: 150.15806111696523
# Prediction BPM 148.15189698079956
# Win start,end: 26750, 27750
# Ground Truth BPM: 149.52780692549845
# Prediction BPM 146.02528450476294
# Win start,end: 27000, 28000
# Ground Truth BPM: 149.2146596858639
# Prediction BPM 154.34699991376326
# Win start,end: 27250, 28250
# Ground Truth BPM: 149.37106918238996
# Prediction BPM 149.24204116236044
# Win start,end: 27500, 28500
# Ground Truth BPM: 149.52780692549845
# Prediction BPM 135.36729988907774
# Win start,end: 27750, 28750
# Ground Truth BPM: 150.15806111696523
# Prediction BPM 112.31192500917173
# Win start,end: 28000, 29000
# Ground Truth BPM: 151.2738853503185
# Prediction BPM 151.61619443100028
# Win start,end: 28250, 29250
# Ground Truth BPM: 152.5940996948118
# Prediction BPM 155.4362858422638
# Win start,end: 28500, 29500
# Ground Truth BPM: 154.00410677618072
# Prediction BPM 153.18427374803798
# Win start,end: 28750, 29750
# Ground Truth BPM: 155.1189245087901
# Prediction BPM 152.15396360828026
# Win start,end: 29000, 30000
# Ground Truth BPM: 156.42151481888033
# Prediction BPM 153.09287360203572
# Win start,end: 29250, 30250
# Ground Truth BPM: 157.7287066246057
# Prediction BPM 156.77375523425175
# Win start,end: 29500, 30500
# Ground Truth BPM: 158.56236786469344
# Prediction BPM 144.2717850247118
# Win start,end: 29750, 30750
# Ground Truth BPM: 159.40488841657813
# Prediction BPM 158.55180243758377
# Win start,end: 30000, 31000
# Ground Truth BPM: 160.55045871559633
# Prediction BPM 136.6094473004151
# Win start,end: 30250, 31250
# Ground Truth BPM: 161.11707841031148
# Prediction BPM 117.87985979294362
# Win start,end: 30500, 31500
# Ground Truth BPM: 161.70431211498973
# Prediction BPM 158.771306773152
# Win start,end: 30750, 31750
# Ground Truth BPM: 162.20391349124614
# Prediction BPM 161.03732825141952
# Win start,end: 31000, 32000
# Ground Truth BPM: 162.33766233766232
# Prediction BPM 148.71258726970177
# Win start,end: 31250, 32250
# Ground Truth BPM: 162.70661157024796
# Prediction BPM 155.22560616464253
# Win start,end: 31500, 32500
# Ground Truth BPM: 162.86644951140065
# Prediction BPM 166.76839745324844
# Win start,end: 31750, 32750
# Ground Truth BPM: 162.87487073422957
# Prediction BPM 155.22560616464253
# Win start,end: 32000, 33000
# Ground Truth BPM: 162.86644951140065
# Prediction BPM 151.7296547245311
# Win start,end: 32250, 33250
# Ground Truth BPM: 163.21243523316062
# Prediction BPM 152.66046516381758
# Win start,end: 32500, 33500
# Ground Truth BPM: 163.7214137214137
# Prediction BPM 161.03732825141952
# Win start,end: 32750, 33750
# Ground Truth BPM: 164.40501043841337
# Prediction BPM 148.22746387526132
# Win start,end: 33000, 34000
# Ground Truth BPM: 164.9214659685864
# Prediction BPM 162.46234540323542
# Win start,end: 33250, 34250
# Ground Truth BPM: 165.44117647058823
# Prediction BPM 151.61619443100028
# Win start,end: 33500, 34500
# Ground Truth BPM: 165.61514195583598
# Prediction BPM 161.03732825141952
# Win start,end: 33750, 34750
# Ground Truth BPM: 165.44117647058823
# Prediction BPM 151.58571147844012
# Win start,end: 34000, 35000
# Ground Truth BPM: 164.9214659685864
# Prediction BPM 150.71991722943682
# Win start,end: 34250, 35250
# Ground Truth BPM: 164.40501043841337
# Prediction BPM 161.1333922732106
# Win start,end: 34500, 35500
# Ground Truth BPM: 163.89177939646203
# Prediction BPM 147.89810825931733
# Win start,end: 34750, 35750
# Ground Truth BPM: 163.04347826086956
# Prediction BPM 138.41053447297077
# Win start,end: 35000, 36000
# Ground Truth BPM: 161.8705035971223
# Prediction BPM 149.75796175593302
# Win start,end: 35250, 36250
# Ground Truth BPM: 160.7717041800643
# Prediction BPM 153.53940451861342
# Win start,end: 35500, 36500
# Ground Truth BPM: 159.06680805938495
# Prediction BPM 143.02574183667713
# Win start,end: 35750, 36750
# Ground Truth BPM: 157.39769150052467
# Prediction BPM 155.16404607555816
# Win start,end: 36000, 37000
# Ground Truth BPM: 156.41293013555787
# Prediction BPM 144.6316322791403
# Win start,end: 36250, 37250
# Ground Truth BPM: 155.60165975103735
# Prediction BPM 144.7646667518018
# Win start,end: 36500, 37500
# Ground Truth BPM: 154.95867768595042
# Prediction BPM 138.98184319460677
# Win start,end: 36750, 37750
# Ground Truth BPM: 154.2207792207792
# Prediction BPM 141.90095364836196
# Win start,end: 0, 1000
# Ground Truth BPM: 84.74576271186442
# Prediction BPM 88.6019272927545
# Win start,end: 250, 1250
# Ground Truth BPM: 89.7714907508161
# Prediction BPM 90.8536909269544
# Win start,end: 500, 1500
# Ground Truth BPM: 92.59259259259258
# Prediction BPM 101.77458011158292
# Win start,end: 750, 1750
# Ground Truth BPM: 88.9967637540453
# Prediction BPM 92.67912571498248
# Win start,end: 1000, 2000
# Ground Truth BPM: 84.3644544431946
# Prediction BPM 93.37115608428323
# Win start,end: 1250, 2250
# Ground Truth BPM: 81.25677139761648
# Prediction BPM 83.8597697711136
# Win start,end: 1500, 2500
# Ground Truth BPM: 76.09921082299888
# Prediction BPM 80.83438713264985
# Win start,end: 1750, 2750
# Ground Truth BPM: 72.90400972053463
# Prediction BPM 93.07275906356666
# Win start,end: 2000, 3000
# Ground Truth BPM: 72.11538461538461
# Prediction BPM 96.78615807669316
# Win start,end: 2250, 3250
# Ground Truth BPM: 70.92198581560284
# Prediction BPM 87.05167377740145
# Win start,end: 2500, 3500
# Ground Truth BPM: 74.58563535911603
# Prediction BPM 86.13568640473528
# Win start,end: 2750, 3750
# Ground Truth BPM: 76.79180887372013
# Prediction BPM 101.82671405086549
# Win start,end: 3000, 4000
# Ground Truth BPM: 73.93209200438116
# Prediction BPM 82.93168535901097
# Win start,end: 3250, 4250
# Ground Truth BPM: 73.05194805194805
# Prediction BPM 84.86535185924693
# Win start,end: 3500, 4500
# Ground Truth BPM: 71.77033492822967
# Prediction BPM 81.5803213772244
# Win start,end: 3750, 4750
# Ground Truth BPM: 69.51596292481977
# Prediction BPM 108.22611613655577
# Win start,end: 4000, 5000
# Ground Truth BPM: 73.449401523395
# Prediction BPM 109.21854695218032
# Win start,end: 4250, 5250
# Ground Truth BPM: 78.04370447450572
# Prediction BPM 85.6238248546993
# Win start,end: 4500, 5500
# Ground Truth BPM: 84.3558282208589
# Prediction BPM 90.42249724838703
# Win start,end: 4750, 5750
# Ground Truth BPM: 90.75907590759076
# Prediction BPM 92.03371627741717
# Win start,end: 5000, 6000
# Ground Truth BPM: 93.53741496598639
# Prediction BPM 107.25399065923727
# Win start,end: 5250, 6250
# Ground Truth BPM: 94.82758620689656
# Prediction BPM 108.62979668705242
# Win start,end: 5500, 6500
# Ground Truth BPM: 96.35974304068522
# Prediction BPM 108.2359027354625
# Win start,end: 5750, 6750
# Ground Truth BPM: 97.29729729729729
# Prediction BPM 108.7359975422396
# Win start,end: 6000, 7000
# Ground Truth BPM: 98.68421052631578
# Prediction BPM 114.54558728801723
# Win start,end: 6250, 7250
# Ground Truth BPM: 101.14107883817427
# Prediction BPM 112.04485463915861
# Win start,end: 6500, 7500
# Ground Truth BPM: 103.68663594470046
# Prediction BPM 140.34478871924006
# Win start,end: 6750, 7750
# Ground Truth BPM: 104.83870967741936
# Prediction BPM 112.65634729125941
# Win start,end: 7000, 8000
# Ground Truth BPM: 104.95156081808395
# Prediction BPM 113.07495068951411
# Win start,end: 7250, 8250
# Ground Truth BPM: 104.05549626467447
# Prediction BPM 147.90018900021005
# Win start,end: 7500, 8500
# Ground Truth BPM: 103.8338658146965
# Prediction BPM 114.28121386511549
# Win start,end: 7750, 8750
# Ground Truth BPM: 103.39342523860022
# Prediction BPM 161.03732825141952
# Win start,end: 8000, 9000
# Ground Truth BPM: 103.39342523860022
# Prediction BPM 111.66472429038882
# Win start,end: 8250, 9250
# Ground Truth BPM: 103.32950631458093
# Prediction BPM 149.34827941193498
# Win start,end: 8500, 9500
# Ground Truth BPM: 103.28389830508476
# Prediction BPM 144.30932947911452
# Win start,end: 8750, 9750
# Ground Truth BPM: 103.68663594470046
# Prediction BPM 131.53480079619655
# Win start,end: 9000, 10000
# Ground Truth BPM: 104.27807486631016
# Prediction BPM 114.72055265012574
# Win start,end: 9250, 10250
# Ground Truth BPM: 104.77299185098951
# Prediction BPM 111.8864769073356
# Win start,end: 9500, 10500
# Ground Truth BPM: 106.55737704918032
# Prediction BPM 117.24574143915297
# Win start,end: 9750, 10750
# Ground Truth BPM: 108.47107438016529
# Prediction BPM 119.5104910212259
# Win start,end: 10000, 11000
# Ground Truth BPM: 109.83263598326361
# Prediction BPM 143.2449907906372
# Win start,end: 10250, 11250
# Ground Truth BPM: 110.79545454545456
# Prediction BPM 135.87678864013324
# Win start,end: 10500, 11500
# Ground Truth BPM: 111.11111111111111
# Prediction BPM 122.1114111919554
# Win start,end: 10750, 11750
# Ground Truth BPM: 111.34676564156946
# Prediction BPM 119.48416468852503
# Win start,end: 11000, 12000
# Ground Truth BPM: 112.17948717948718
# Prediction BPM 115.28960231323899
# Win start,end: 11250, 12250
# Ground Truth BPM: 112.66094420600857
# Prediction BPM 135.55971207044695
# Win start,end: 11500, 12500
# Ground Truth BPM: 113.39092872570194
# Prediction BPM 118.45159583128121
# Win start,end: 11750, 12750
# Ground Truth BPM: 114.37908496732025
# Prediction BPM 140.962161013982
# Win start,end: 12000, 13000
# Ground Truth BPM: 115.89403973509933
# Prediction BPM 128.7761791128167
# Win start,end: 12250, 13250
# Ground Truth BPM: 117.4321503131524
# Prediction BPM 153.71898000763704
# Win start,end: 12500, 13500
# Ground Truth BPM: 119.17372881355934
# Prediction BPM 117.22407889595182
# Win start,end: 12750, 13750
# Ground Truth BPM: 120.70815450643775
# Prediction BPM 129.8157558816763
# Win start,end: 13000, 14000
# Ground Truth BPM: 122.01735357917569
# Prediction BPM 121.02099443015075
# Win start,end: 13250, 14250
# Ground Truth BPM: 123.22015334063528
# Prediction BPM 136.4553895498835
# Win start,end: 13500, 14500
# Ground Truth BPM: 124.48132780082987
# Prediction BPM 137.4415298809013
# Win start,end: 13750, 14750
# Ground Truth BPM: 125.78616352201259
# Prediction BPM 149.06564641763086
# Win start,end: 14000, 15000
# Ground Truth BPM: 126.98412698412699
# Prediction BPM 129.0444956274839
# Win start,end: 14250, 15250
# Ground Truth BPM: 128.3422459893048
# Prediction BPM 129.7350812502419
# Win start,end: 14500, 15500
# Ground Truth BPM: 129.44983818770226
# Prediction BPM 133.10693192641017
# Win start,end: 14750, 15750
# Ground Truth BPM: 130.57671381936888
# Prediction BPM 139.28223087456658
# Win start,end: 15000, 16000
# Ground Truth BPM: 131.44329896907217
# Prediction BPM 136.7519140128296
# Win start,end: 15250, 16250
# Ground Truth BPM: 132.3042998897464
# Prediction BPM 121.6618609538479
# Win start,end: 15500, 16500
# Ground Truth BPM: 132.8125
# Prediction BPM 146.83279655184842
# Win start,end: 15750, 16750
# Ground Truth BPM: 133.50785340314138
# Prediction BPM 131.32752984526937
# Win start,end: 16000, 17000
# Ground Truth BPM: 134.63569165786694
# Prediction BPM 148.67105615705685
# Win start,end: 16250, 17250
# Ground Truth BPM: 135.63829787234044
# Prediction BPM 135.74340617865332
# Win start,end: 16500, 17500
# Ground Truth BPM: 136.94951664876476
# Prediction BPM 150.3311615231983
# Win start,end: 16750, 17750
# Ground Truth BPM: 137.75510204081633
# Prediction BPM 136.7519140128296
# Win start,end: 17000, 18000
# Ground Truth BPM: 138.73775843307942
# Prediction BPM 154.893514148377
# Win start,end: 17250, 18250
# Ground Truth BPM: 139.17525773195877
# Prediction BPM 136.4553895498835
# Win start,end: 17500, 18500
# Ground Truth BPM: 139.31888544891643
# Prediction BPM 134.89779911279672
# Win start,end: 17750, 18750
# Ground Truth BPM: 139.64950711938664
# Prediction BPM 148.67105615705685
# Win start,end: 18000, 19000
# Ground Truth BPM: 140.04149377593362
# Prediction BPM 143.36215250009073
# Win start,end: 18250, 19250
# Ground Truth BPM: 140.4786680541103
# Prediction BPM 150.71991722943682
# Win start,end: 18500, 19500
# Ground Truth BPM: 140.8839779005525
# Prediction BPM 137.05569937660002
# Win start,end: 18750, 19750
# Ground Truth BPM: 141.21338912133893
# Prediction BPM 157.04385127823508
# Win start,end: 19000, 20000
# Ground Truth BPM: 141.21338912133893
# Prediction BPM 135.8170555163247
# Win start,end: 19250, 20250
# Ground Truth BPM: 141.03982300884957
# Prediction BPM 147.02015997231013
# Win start,end: 19500, 20500
# Ground Truth BPM: 140.33264033264032
# Prediction BPM 138.68628436979336
# Win start,end: 19750, 20750
# Ground Truth BPM: 139.60703205791108
# Prediction BPM 143.36215250009073
# Win start,end: 20000, 21000
# Ground Truth BPM: 139.19213973799125
# Prediction BPM 135.95939556627826
# Win start,end: 20250, 21250
# Ground Truth BPM: 138.73775843307942
# Prediction BPM 109.8804048272059
# Win start,end: 20500, 21500
# Ground Truth BPM: 139.03192584963955
# Prediction BPM 140.34478871924006
# Win start,end: 20750, 21750
# Ground Truth BPM: 139.34426229508196
# Prediction BPM 133.65175552997505
# Win start,end: 21000, 22000
# Ground Truth BPM: 138.88888888888889
# Prediction BPM 139.16533243519848
# Win start,end: 21250, 22250
# Ground Truth BPM: 138.46153846153845
# Prediction BPM 134.7339817630725
# Win start,end: 21500, 22500
# Ground Truth BPM: 137.6889848812095
# Prediction BPM 136.03793582205023
# Win start,end: 21750, 22750
# Ground Truth BPM: 136.5015166835187
# Prediction BPM 131.55939140364475
# Win start,end: 22000, 23000
# Ground Truth BPM: 134.77801268498945
# Prediction BPM 135.57325186067592
# Win start,end: 22250, 23250
# Ground Truth BPM: 133.33333333333334
# Prediction BPM 130.20340398121004
# Win start,end: 22500, 23500
# Ground Truth BPM: 131.98757763975155
# Prediction BPM 128.00089834723403
# Win start,end: 22750, 23750
# Ground Truth BPM: 130.1518438177874
# Prediction BPM 122.26004546203032
# Win start,end: 23000, 24000
# Ground Truth BPM: 128.3422459893048
# Prediction BPM 141.81276183101448
# Win start,end: 23250, 24250
# Ground Truth BPM: 126.18296529968455
# Prediction BPM 131.304486182735
# Win start,end: 23500, 24500
# Ground Truth BPM: 123.8986784140969
# Prediction BPM 144.60694466286088
# Win start,end: 23750, 24750
# Ground Truth BPM: 123.4906695938529
# Prediction BPM 124.5887908844831
# Win start,end: 24000, 25000
# Ground Truth BPM: 122.95081967213113
# Prediction BPM 126.42329719943088
# Win start,end: 24250, 25250
# Ground Truth BPM: 122.14983713355049
# Prediction BPM 120.00754856922278
# Win start,end: 24500, 25500
# Ground Truth BPM: 121.22844827586205
# Prediction BPM 119.42336417970442
# Win start,end: 24750, 25750
# Ground Truth BPM: 120.1923076923077
# Prediction BPM 137.34866353809971
# Win start,end: 25000, 26000
# Ground Truth BPM: 119.30010604453871
# Prediction BPM 125.29547624094846
# Win start,end: 25250, 26250
# Ground Truth BPM: 118.67088607594937
# Prediction BPM 106.71190365626062
# Win start,end: 25500, 26500
# Ground Truth BPM: 118.79619852164731
# Prediction BPM 123.12771923284
# Win start,end: 25750, 26750
# Ground Truth BPM: 119.17372881355934
# Prediction BPM 105.47202012919702
# Win start,end: 26000, 27000
# Ground Truth BPM: 119.4267515923567
# Prediction BPM 123.22499686979032
# Win start,end: 26250, 27250
# Ground Truth BPM: 120.57877813504821
# Prediction BPM 126.18064415992728
# Win start,end: 26500, 27500
# Ground Truth BPM: 121.45748987854252
# Prediction BPM 128.99298444318373
# Win start,end: 26750, 27750
# Ground Truth BPM: 121.95121951219512
# Prediction BPM 120.04743638156123
# Win start,end: 27000, 28000
# Ground Truth BPM: 122.82497441146367
# Prediction BPM 154.95034625436497
# Win start,end: 27250, 28250
# Ground Truth BPM: 123.07692307692308
# Prediction BPM 127.79972386611607
# Win start,end: 27500, 28500
# Ground Truth BPM: 124.03528114663726
# Prediction BPM 127.49244171002167
# Win start,end: 27750, 28750
# Ground Truth BPM: 125.83892617449665
# Prediction BPM 138.98184319460677
# Win start,end: 28000, 29000
# Ground Truth BPM: 127.5239107332625
# Prediction BPM 160.93094918030963
# Win start,end: 28250, 29250
# Ground Truth BPM: 128.61736334405143
# Prediction BPM 148.67105615705685
# Win start,end: 28500, 29500
# Ground Truth BPM: 129.58963282937364
# Prediction BPM 134.82603518640795
# Win start,end: 28750, 29750
# Ground Truth BPM: 130.50153531218015
# Prediction BPM 149.06564641763086
# Win start,end: 29000, 30000
# Ground Truth BPM: 131.86813186813185
# Prediction BPM 154.9405586475769
# Win start,end: 29250, 30250
# Ground Truth BPM: 133.3682008368201
# Prediction BPM 136.4553895498835
# Win start,end: 29500, 30500
# Ground Truth BPM: 135.0635593220339
# Prediction BPM 156.91012210838338
# Win start,end: 29750, 30750
# Ground Truth BPM: 137.09677419354838
# Prediction BPM 145.07694441229344
# Win start,end: 30000, 31000
# Ground Truth BPM: 138.88888888888889
# Prediction BPM 142.604285148846
# Win start,end: 30250, 31250
# Ground Truth BPM: 140.33264033264032
# Prediction BPM 161.03732825141952
# Win start,end: 30500, 31500
# Ground Truth BPM: 140.91858037578288
# Prediction BPM 142.31340706839575
# Win start,end: 30750, 31750
# Ground Truth BPM: 141.6579223504722
# Prediction BPM 143.36215250009073
# Win start,end: 31000, 32000
# Ground Truth BPM: 141.50943396226415
# Prediction BPM 148.67105615705685
# Win start,end: 31250, 32250
# Ground Truth BPM: 141.66666666666669
# Prediction BPM 144.3557343390991
# Win start,end: 31500, 32500
# Ground Truth BPM: 141.6579223504722
# Prediction BPM 148.67105615705685
# Win start,end: 31750, 32750
# Ground Truth BPM: 141.95583596214513
# Prediction BPM 124.29604814670667
# Win start,end: 32000, 33000
# Ground Truth BPM: 142.7061310782241
# Prediction BPM 148.67105615705685
# Win start,end: 32250, 33250
# Ground Truth BPM: 143.36016096579476
# Prediction BPM 143.50491485083575
# Win start,end: 32500, 33500
# Ground Truth BPM: 144.23076923076923
# Prediction BPM 148.67105615705685
# Win start,end: 32750, 33750
# Ground Truth BPM: 145.00537056928033
# Prediction BPM 144.36455185044224
# Win start,end: 33000, 34000
# Ground Truth BPM: 146.26218851570965
# Prediction BPM 151.7296547245311
# Win start,end: 33250, 34250
# Ground Truth BPM: 147.21919302071973
# Prediction BPM 135.87678864013324
# Win start,end: 33500, 34500
# Ground Truth BPM: 148.12889812889813
# Prediction BPM 149.9309323573266
# Win start,end: 33750, 34750
# Ground Truth BPM: 148.59228362878
# Prediction BPM 144.56174534840372
# Win start,end: 34000, 35000
# Ground Truth BPM: 148.59228362878
# Prediction BPM 146.21832087577963
# Win start,end: 34250, 35250
# Ground Truth BPM: 148.12889812889813
# Prediction BPM 145.59873603659275
# Win start,end: 34500, 35500
# Ground Truth BPM: 147.36297828335057
# Prediction BPM 142.9839761283377
# Win start,end: 34750, 35750
# Ground Truth BPM: 146.00409836065575
# Prediction BPM 139.33878645496833
# Win start,end: 35000, 36000
# Ground Truth BPM: 144.53961456102783
# Prediction BPM 141.3397562779392
# Win start,end: 35250, 36250
# Ground Truth BPM: 143.46439957492032
# Prediction BPM 142.4234968047498
# Win start,end: 35500, 36500
# Ground Truth BPM: 142.40506329113924
# Prediction BPM 138.60839988848292
# Win start,end: 35750, 36750
# Ground Truth BPM: 141.50943396226415
# Prediction BPM 147.68014291709994
# Win start,end: 36000, 37000
# Ground Truth BPM: 140.33264033264032
# Prediction BPM 108.22611613655577
# Win start,end: 36250, 37250
# Ground Truth BPM: 138.46153846153845
# Prediction BPM 138.83860036139507
# Win start,end: 36500, 37500
# Ground Truth BPM: 136.80257510729612
# Prediction BPM 132.77376871023387
# Win start,end: 36750, 37750
# Ground Truth BPM: 135.20678685047722
# Prediction BPM 129.06021329704447
# Win start,end: 0, 1000
# Ground Truth BPM: 104.0555
# Prediction BPM 125.72637202553032
# Win start,end: 250, 1250
# Ground Truth BPM: 104.2781
# Prediction BPM 97.86884559586726
# Win start,end: 500, 1500
# Ground Truth BPM: 102.0408
# Prediction BPM 99.32069888446
# Win start,end: 750, 1750
# Ground Truth BPM: 98.2533
# Prediction BPM 97.8740187231791
# Win start,end: 1000, 2000
# Ground Truth BPM: 94.2857
# Prediction BPM 92.07086185762873
# Win start,end: 1250, 2250
# Ground Truth BPM: 94.3396
# Prediction BPM 96.62160707276622
# Win start,end: 1500, 2500
# Ground Truth BPM: 95.6429
# Prediction BPM 94.25515662470927
# Win start,end: 1750, 2750
# Ground Truth BPM: 96.2567
# Prediction BPM 95.34474996912002
# Win start,end: 2000, 3000
# Ground Truth BPM: 95.2381
# Prediction BPM 109.29447510437494
# Win start,end: 2250, 3250
# Ground Truth BPM: 91.7686
# Prediction BPM 88.77912652764545
# Win start,end: 2500, 3500
# Ground Truth BPM: 91.4634
# Prediction BPM 93.35826694250196
# Win start,end: 2750, 3750
# Ground Truth BPM: 90.9592
# Prediction BPM 105.46126038457072
# Win start,end: 3000, 4000
# Ground Truth BPM: 89.1892
# Prediction BPM 96.3944785021613
# Win start,end: 3250, 4250
# Ground Truth BPM: 84.6501
# Prediction BPM 87.84349892055121
# Win start,end: 3500, 4500
# Ground Truth BPM: 83.7054
# Prediction BPM 108.55088926737024
# Win start,end: 3750, 4750
# Ground Truth BPM: 86.0271
# Prediction BPM 95.21672066699759
# Win start,end: 4000, 5000
# Ground Truth BPM: 90.1639
# Prediction BPM 94.67167562269569
# Win start,end: 4250, 5250
# Ground Truth BPM: 93.361
# Prediction BPM 100.26959570882651
# Win start,end: 4500, 5500
# Ground Truth BPM: 95.0461
# Prediction BPM 97.10799411455642
# Win start,end: 4750, 5750
# Ground Truth BPM: 97.1922
# Prediction BPM 111.72183565778595
# Win start,end: 5000, 6000
# Ground Truth BPM: 99.4475
# Prediction BPM 113.85044001268042
# Win start,end: 5250, 6250
# Ground Truth BPM: 101.6949
# Prediction BPM 136.30516214540503
# Win start,end: 5500, 6500
# Ground Truth BPM: 103.1746
# Prediction BPM 106.60598829116162
# Win start,end: 5750, 6750
# Ground Truth BPM: 104.1667
# Prediction BPM 100.73778792389786
# Win start,end: 6000, 7000
# Ground Truth BPM: 105.2916
# Prediction BPM 107.28793347556413
# Win start,end: 6250, 7250
# Ground Truth BPM: 107.0252
# Prediction BPM 113.57592582303597
# Win start,end: 6500, 7500
# Ground Truth BPM: 108.2131
# Prediction BPM 152.85451132377818
# Win start,end: 6750, 7750
# Ground Truth BPM: 109.0604
# Prediction BPM 120.07537493502
# Win start,end: 7000, 8000
# Ground Truth BPM: 109.4891
# Prediction BPM 121.18661899930476
# Win start,end: 7250, 8250
# Ground Truth BPM: 110.2941
# Prediction BPM 131.08332584180968
# Win start,end: 7500, 8500
# Ground Truth BPM: 111.7021
# Prediction BPM 122.03124359303516
# Win start,end: 7750, 8750
# Ground Truth BPM: 113.0248
# Prediction BPM 117.88799091427786
# Win start,end: 8000, 9000
# Ground Truth BPM: 114.5038
# Prediction BPM 118.0062011613992
# Win start,end: 8250, 9250
# Ground Truth BPM: 114.8796
# Prediction BPM 148.1913428519733
# Win start,end: 8500, 9500
# Ground Truth BPM: 115.5031
# Prediction BPM 125.42653029093546
# Win start,end: 8750, 9750
# Ground Truth BPM: 115.8599
# Prediction BPM 139.22888673709838
# Win start,end: 9000, 10000
# Ground Truth BPM: 116.0221
# Prediction BPM 127.94685729088765
# Win start,end: 9250, 10250
# Ground Truth BPM: 116.0221
# Prediction BPM 126.61713454683357
# Win start,end: 9500, 10500
# Ground Truth BPM: 116.2791
# Prediction BPM 130.7973289713583
# Win start,end: 9750, 10750
# Ground Truth BPM: 117.0569
# Prediction BPM 120.78389195095953
# Win start,end: 10000, 11000
# Ground Truth BPM: 117.3097
# Prediction BPM 125.53019252011062
# Win start,end: 10250, 11250
# Ground Truth BPM: 117.6778
# Prediction BPM 119.73877365298789
# Win start,end: 10500, 11500
# Ground Truth BPM: 118.5458
# Prediction BPM 128.98246807301405
# Win start,end: 10750, 11750
# Ground Truth BPM: 119.6809
# Prediction BPM 118.65739350394296
# Win start,end: 11000, 12000
# Ground Truth BPM: 121.7532
# Prediction BPM 136.4553895498835
# Win start,end: 11250, 12250
# Ground Truth BPM: 124.6106
# Prediction BPM 150.05849930000002
# Win start,end: 11500, 12500
# Ground Truth BPM: 126.4489
# Prediction BPM 134.31063738627498
# Win start,end: 11750, 12750
# Ground Truth BPM: 128.4797
# Prediction BPM 129.0444956274839
# Win start,end: 12000, 13000
# Ground Truth BPM: 130.2349
# Prediction BPM 144.3557343390991
# Win start,end: 12250, 13250
# Ground Truth BPM: 132.1586
# Prediction BPM 138.60394084545774
# Win start,end: 12500, 13500
# Ground Truth BPM: 134.0694
# Prediction BPM 141.11932044542732
# Win start,end: 12750, 13750
# Ground Truth BPM: 135.6383
# Prediction BPM 128.99298444318373
# Win start,end: 13000, 14000
# Ground Truth BPM: 137.2443
# Prediction BPM 145.07694441229344
# Win start,end: 13250, 14250
# Ground Truth BPM: 139.0319
# Prediction BPM 155.4362858422638
# Win start,end: 13500, 14500
# Ground Truth BPM: 141.0658
# Prediction BPM 137.39811690548393
# Win start,end: 13750, 14750
# Ground Truth BPM: 143.3602
# Prediction BPM 149.06564641763086
# Win start,end: 14000, 15000
# Ground Truth BPM: 145.7055
# Prediction BPM 151.61619443100028
# Win start,end: 14250, 15250
# Ground Truth BPM: 147.5155
# Prediction BPM 143.36215250009073
# Win start,end: 14500, 15500
# Ground Truth BPM: 148.9028
# Prediction BPM 142.2467302716009
# Win start,end: 14750, 15750
# Ground Truth BPM: 149.3711
# Prediction BPM 150.71991722943682
# Win start,end: 15000, 16000
# Ground Truth BPM: 149.0066
# Prediction BPM 151.61619443100028
# Win start,end: 15250, 16250
# Ground Truth BPM: 148.8423
# Prediction BPM 137.1385710866932
# Win start,end: 15500, 16500
# Ground Truth BPM: 148.1888
# Prediction BPM 136.7519140128296
# Win start,end: 15750, 16750
# Ground Truth BPM: 147.541
# Prediction BPM 151.61619443100028
# Win start,end: 16000, 17000
# Ground Truth BPM: 147.5155
# Prediction BPM 150.3774583739041
# Win start,end: 16250, 17250
# Ground Truth BPM: 147.363
# Prediction BPM 139.29370224270647
# Win start,end: 16500, 17500
# Ground Truth BPM: 147.6684
# Prediction BPM 151.61619443100028
# Win start,end: 16750, 17750
# Ground Truth BPM: 148.4375
# Prediction BPM 150.3774583739041
# Win start,end: 17000, 18000
# Ground Truth BPM: 149.5278
# Prediction BPM 148.15189698079956
# Win start,end: 17250, 18250
# Ground Truth BPM: 150.4752
# Prediction BPM 160.80956850040863
# Win start,end: 17500, 18500
# Ground Truth BPM: 151.2739
# Prediction BPM 148.67288887245837
# Win start,end: 17750, 18750
# Ground Truth BPM: 152.0811
# Prediction BPM 149.91280312984108
# Win start,end: 18000, 19000
# Ground Truth BPM: 152.7331
# Prediction BPM 135.87678864013324
# Win start,end: 18250, 19250
# Ground Truth BPM: 153.5312
# Prediction BPM 161.03732825141952
# Win start,end: 18500, 19500
# Ground Truth BPM: 153.6885
# Prediction BPM 153.8138579693273
# Win start,end: 18750, 19750
# Ground Truth BPM: 153.5312
# Prediction BPM 137.91315891655603
# Win start,end: 19000, 20000
# Ground Truth BPM: 153.0612
# Prediction BPM 154.20903384645203
# Win start,end: 19250, 20250
# Ground Truth BPM: 151.919
# Prediction BPM 152.15083086076055
# Win start,end: 19500, 20500
# Ground Truth BPM: 150.7937
# Prediction BPM 127.53631763732683
# Win start,end: 19750, 20750
# Ground Truth BPM: 149.8423
# Prediction BPM 116.47790462328359
# Win start,end: 20000, 21000
# Ground Truth BPM: 149.0586
# Prediction BPM 134.11427872063334
# Win start,end: 20250, 21250
# Ground Truth BPM: 148.4375
# Prediction BPM 130.10046603878249
# Win start,end: 20500, 21500
# Ground Truth BPM: 147.5155
# Prediction BPM 122.10605626987828
# Win start,end: 20750, 21750
# Ground Truth BPM: 146.5798
# Prediction BPM 139.89886052592942
# Win start,end: 21000, 22000
# Ground Truth BPM: 145.6311
# Prediction BPM 138.13419261225584
# Win start,end: 21250, 22250
# Ground Truth BPM: 144.8498
# Prediction BPM 140.37084178583825
# Win start,end: 21500, 22500
# Ground Truth BPM: 144.2308
# Prediction BPM 133.6532648383969
# Win start,end: 21750, 22750
# Ground Truth BPM: 143.6492
# Prediction BPM 143.7086342536746
# Win start,end: 22000, 23000
# Ground Truth BPM: 143.0085
# Prediction BPM 138.51293585418378
# Win start,end: 22250, 23250
# Ground Truth BPM: 141.8067
# Prediction BPM 138.6146079453889
# Win start,end: 22500, 23500
# Ground Truth BPM: 140.625
# Prediction BPM 137.78675187735004
# Win start,end: 22750, 23750
# Ground Truth BPM: 139.9561
# Prediction BPM 109.58220801396828
# Win start,end: 23000, 24000
# Ground Truth BPM: 138.8889
# Prediction BPM 139.97484170830546
# Win start,end: 23250, 24250
# Ground Truth BPM: 138.1365
# Prediction BPM 132.91911517493196
# Win start,end: 23500, 24500
# Ground Truth BPM: 136.6559
# Prediction BPM 135.81045618009432
# Win start,end: 23750, 24750
# Ground Truth BPM: 135.4942
# Prediction BPM 132.0557475642411
# Win start,end: 24000, 25000
# Ground Truth BPM: 134.0694
# Prediction BPM 134.1484807013599
# Win start,end: 24250, 25250
# Ground Truth BPM: 133.3682
# Prediction BPM 127.31414164088147
# Win start,end: 24500, 25500
# Ground Truth BPM: 132.5364
# Prediction BPM 103.11920096155701
# Win start,end: 24750, 25750
# Ground Truth BPM: 131.3079
# Prediction BPM 125.78307904581366
# Win start,end: 25000, 26000
# Ground Truth BPM: 130.5767
# Prediction BPM 130.81731131315806
# Win start,end: 25250, 26250
# Ground Truth BPM: 129.1712
# Prediction BPM 131.25736901164444
# Win start,end: 25500, 26500
# Ground Truth BPM: 127.2534
# Prediction BPM 131.88990699824507
# Win start,end: 25750, 26750
# Ground Truth BPM: 125.6545
# Prediction BPM 123.17007412253912
# Win start,end: 26000, 27000
# Ground Truth BPM: 125.1303
# Prediction BPM 127.44368731686795
# Win start,end: 26250, 27250
# Ground Truth BPM: 126.3158
# Prediction BPM 129.06268579703465
# Win start,end: 26500, 27500
# Ground Truth BPM: 129.1712
# Prediction BPM 160.93094918030963
# Win start,end: 26750, 27750
# Ground Truth BPM: 132.0132
# Prediction BPM 127.43187938458931
# Win start,end: 27000, 28000
# Ground Truth BPM: 133.9286
# Prediction BPM 131.17933157415288
# Win start,end: 27250, 28250
# Ground Truth BPM: 135.3503
# Prediction BPM 148.22746387526132
# Win start,end: 27500, 28500
# Ground Truth BPM: 136.6559
# Prediction BPM 156.03793698563615
# Win start,end: 27750, 28750
# Ground Truth BPM: 137.8958
# Prediction BPM 148.1913428519733
# Win start,end: 28000, 29000
# Ground Truth BPM: 139.3443
# Prediction BPM 143.33463664402598
# Win start,end: 28250, 29250
# Ground Truth BPM: 140.4787
# Prediction BPM 144.7583130629989
# Win start,end: 28500, 29500
# Ground Truth BPM: 141.8067
# Prediction BPM 142.5116111443707
# Win start,end: 28750, 29750
# Ground Truth BPM: 142.7061
# Prediction BPM 138.27338768752176
# Win start,end: 29000, 30000
# Ground Truth BPM: 143.6492
# Prediction BPM 153.87919269064253
# Win start,end: 29250, 30250
# Ground Truth BPM: 144.385
# Prediction BPM 142.54605793206824
# Win start,end: 29500, 30500
# Ground Truth BPM: 145.0054
# Prediction BPM 143.36215250009073
# Win start,end: 29750, 30750
# Ground Truth BPM: 145.4741
# Prediction BPM 142.8886522227009
# Win start,end: 30000, 31000
# Ground Truth BPM: 145.7883
# Prediction BPM 157.07792191586066
# Win start,end: 30250, 31250
# Ground Truth BPM: 146.4543
# Prediction BPM 147.37196509161524
# Win start,end: 30500, 31500
# Ground Truth BPM: 147.0588
# Prediction BPM 147.76330371436234
# Win start,end: 30750, 31750
# Ground Truth BPM: 148.1289
# Prediction BPM 137.65889737933463
# Win start,end: 31000, 32000
# Ground Truth BPM: 149.2147
# Prediction BPM 136.8360550082504
# Win start,end: 31250, 32250
# Ground Truth BPM: 151.1135
# Prediction BPM 129.21569999473803
# Win start,end: 31500, 32500
# Ground Truth BPM: 152.897
# Prediction BPM 162.544595682925
# Win start,end: 31750, 32750
# Ground Truth BPM: 155.4404
# Prediction BPM 152.92049551169907
# Win start,end: 32000, 33000
# Ground Truth BPM: 157.2327
# Prediction BPM 148.83707953090268
# Win start,end: 32250, 33250
# Ground Truth BPM: 158.5624
# Prediction BPM 157.77742839640632
# Win start,end: 32500, 33500
# Ground Truth BPM: 159.7363
# Prediction BPM 156.8931010261576
# Win start,end: 32750, 33750
# Ground Truth BPM: 160.0854
# Prediction BPM 161.69814749404804
# Win start,end: 33000, 34000
# Ground Truth BPM: 160.4278
# Prediction BPM 151.40762571131364
# Win start,end: 33250, 34250
# Ground Truth BPM: 160.387
# Prediction BPM 155.41270446878443
# Win start,end: 33500, 34500
# Ground Truth BPM: 159.7444
# Prediction BPM 152.51462881593469
# Win start,end: 33750, 34750
# Ground Truth BPM: 158.8983
# Prediction BPM 144.07763015398376
# Win start,end: 34000, 35000
# Ground Truth BPM: 157.7287
# Prediction BPM 115.41915654343856
# Win start,end: 34250, 35250
# Ground Truth BPM: 157.0681
# Prediction BPM 151.95703915925031
# Win start,end: 34500, 35500
# Ground Truth BPM: 156.9038
# Prediction BPM 148.1913428519733
# Win start,end: 34750, 35750
# Ground Truth BPM: 156.5762
# Prediction BPM 157.36453138612794
# Win start,end: 0, 1000
# Ground Truth BPM: 82.873
# Prediction BPM 89.76871085868137
# Win start,end: 250, 1250
# Ground Truth BPM: 79.318
# Prediction BPM 83.78581493852012
# Win start,end: 500, 1500
# Ground Truth BPM: 71.278
# Prediction BPM 80.94105448130443
# Win start,end: 750, 1750
# Ground Truth BPM: 66.667
# Prediction BPM 100.40259314855889
# Win start,end: 1000, 2000
# Ground Truth BPM: 66.298
# Prediction BPM 94.69695918386071
# Win start,end: 1250, 2250
# Ground Truth BPM: 71.128
# Prediction BPM 81.53650146836061
# Win start,end: 1500, 2500
# Ground Truth BPM: 77.231
# Prediction BPM 80.86402986126852
# Win start,end: 1750, 2750
# Ground Truth BPM: 77.945
# Prediction BPM 97.43607619400682
# Win start,end: 2000, 3000
# Ground Truth BPM: 76.967
# Prediction BPM 87.48096362393144
# Win start,end: 2250, 3250
# Ground Truth BPM: 74.503
# Prediction BPM 94.02819086264726
# Win start,end: 2500, 3500
# Ground Truth BPM: 75.758
# Prediction BPM 116.27582562207316
# Win start,end: 2750, 3750
# Ground Truth BPM: 80.043
# Prediction BPM 93.49356741748396
# Win start,end: 3000, 4000
# Ground Truth BPM: 83.841
# Prediction BPM 100.98430874299711
# Win start,end: 3250, 4250
# Ground Truth BPM: 87.58
# Prediction BPM 129.77776202605202
# Win start,end: 3500, 4500
# Ground Truth BPM: 90.164
# Prediction BPM 114.77064229700383
# Win start,end: 3750, 4750
# Ground Truth BPM: 91.362
# Prediction BPM 95.50578525254807
# Win start,end: 4000, 5000
# Ground Truth BPM: 91.565
# Prediction BPM 110.17371115238106
# Win start,end: 4250, 5250
# Ground Truth BPM: 92.489
# Prediction BPM 130.3742326363097
# Win start,end: 4500, 5500
# Ground Truth BPM: 91.362
# Prediction BPM 100.96226212129427
# Win start,end: 4750, 5750
# Ground Truth BPM: 88.805
# Prediction BPM 94.4647371013965
# Win start,end: 5000, 6000
# Ground Truth BPM: 87.58
# Prediction BPM 104.53211377402472
# Win start,end: 5250, 6250
# Ground Truth BPM: 87.953
# Prediction BPM 116.70148445674394
# Win start,end: 5500, 6500
# Ground Truth BPM: 91.463
# Prediction BPM 101.33593842864788
# Win start,end: 5750, 6750
# Ground Truth BPM: 95.376
# Prediction BPM 109.800160490267
# Win start,end: 6000, 7000
# Ground Truth BPM: 97.72
# Prediction BPM 102.04539552904785
# Win start,end: 6250, 7250
# Ground Truth BPM: 97.508
# Prediction BPM 105.97939806658401
# Win start,end: 6500, 7500
# Ground Truth BPM: 98.039
# Prediction BPM 117.36251799618486
# Win start,end: 6750, 7750
# Ground Truth BPM: 99.693
# Prediction BPM 109.39960133594616
# Win start,end: 7000, 8000
# Ground Truth BPM: 100.784
# Prediction BPM 104.2406340663178
# Win start,end: 7250, 8250
# Ground Truth BPM: 102.632
# Prediction BPM 111.41594232469107
# Win start,end: 7500, 8500
# Ground Truth BPM: 103.175
# Prediction BPM 106.60598829116162
# Win start,end: 7750, 8750
# Ground Truth BPM: 102.389
# Prediction BPM 139.29975300331785
# Win start,end: 8000, 9000
# Ground Truth BPM: 100.784
# Prediction BPM 101.21212656770757
# Win start,end: 8250, 9250
# Ground Truth BPM: 97.72
# Prediction BPM 139.24808977688485
# Win start,end: 8500, 9500
# Ground Truth BPM: 96.257
# Prediction BPM 107.12089830839673
# Win start,end: 8750, 9750
# Ground Truth BPM: 96.257
# Prediction BPM 93.3996131813375
# Win start,end: 9000, 10000
# Ground Truth BPM: 95.486
# Prediction BPM 97.50544395104328
# Win start,end: 9250, 10250
# Ground Truth BPM: 96.463
# Prediction BPM 112.85502620210718
# Win start,end: 9500, 10500
# Ground Truth BPM: 95.847
# Prediction BPM 92.13190398879748
# Win start,end: 9750, 10750
# Ground Truth BPM: 96.051
# Prediction BPM 104.96954508333312
# Win start,end: 10000, 11000
# Ground Truth BPM: 95.541
# Prediction BPM 104.8193696518205
# Win start,end: 10250, 11250
# Ground Truth BPM: 94.719
# Prediction BPM 107.15889824223625
# Win start,end: 10500, 11500
# Ground Truth BPM: 90.659
# Prediction BPM 90.20028611948824
# Win start,end: 10750, 11750
# Ground Truth BPM: 87.394
# Prediction BPM 94.56400320239437
# Win start,end: 11000, 12000
# Ground Truth BPM: 84.746
# Prediction BPM 97.93176000490863
# Win start,end: 11250, 12250
# Ground Truth BPM: 84.65
# Prediction BPM 99.17503236813172
# Win start,end: 11500, 12500
# Ground Truth BPM: 89.674
# Prediction BPM 131.72558215889393
# Win start,end: 11750, 12750
# Ground Truth BPM: 92.801
# Prediction BPM 140.8933541771494
# Win start,end: 12000, 13000
# Ground Truth BPM: 94.837
# Prediction BPM 102.01560791171016
# Win start,end: 12250, 13250
# Ground Truth BPM: 97.695
# Prediction BPM 90.84742790100435
# Win start,end: 12500, 13500
# Ground Truth BPM: 99.119
# Prediction BPM 104.48190367929764
# Win start,end: 12750, 13750
# Ground Truth BPM: 102.389
# Prediction BPM 99.96785573589898
# Win start,end: 13000, 14000
# Ground Truth BPM: 103.066
# Prediction BPM 97.76576123754546
# Win start,end: 13250, 14250
# Ground Truth BPM: 103.448
# Prediction BPM 100.71611253378538
# Win start,end: 13500, 14500
# Ground Truth BPM: 103.503
# Prediction BPM 103.46652772324387
# Win start,end: 13750, 14750
# Ground Truth BPM: 100.334
# Prediction BPM 110.07931689394411
# Win start,end: 14000, 15000
# Ground Truth BPM: 96.257
# Prediction BPM 105.25387036875152
# Win start,end: 14250, 15250
# Ground Truth BPM: 93.75
# Prediction BPM 105.45951316662709
# Win start,end: 14500, 15500
# Ground Truth BPM: 91.16
# Prediction BPM 97.11019084176095
# Win start,end: 14750, 15750
# Ground Truth BPM: 96.051
# Prediction BPM 97.6533383345091
# Win start,end: 15000, 16000
# Ground Truth BPM: 101.01
# Prediction BPM 96.17559588326321
# Win start,end: 15250, 16250
# Ground Truth BPM: 104.726
# Prediction BPM 97.23292363342915
# Win start,end: 15500, 16500
# Ground Truth BPM: 107.143
# Prediction BPM 103.91067217735794
# Win start,end: 15750, 16750
# Ground Truth BPM: 105.748
# Prediction BPM 108.82808629713169
# Win start,end: 16000, 17000
# Ground Truth BPM: 102.524
# Prediction BPM 104.02728619145299
# Win start,end: 16250, 17250
# Ground Truth BPM: 96.051
# Prediction BPM 95.99245030429992
# Win start,end: 16500, 17500
# Ground Truth BPM: 93.652
# Prediction BPM 90.9607138218221
# Win start,end: 16750, 17750
# Ground Truth BPM: 92.697
# Prediction BPM 95.92460051432278
# Win start,end: 17000, 18000
# Ground Truth BPM: 94.502
# Prediction BPM 96.50278669227515
# Win start,end: 17250, 18250
# Ground Truth BPM: 95.486
# Prediction BPM 93.52578655872512
# Win start,end: 17500, 18500
# Ground Truth BPM: 93.857
# Prediction BPM 101.74718335003398
# Win start,end: 17750, 18750
# Ground Truth BPM: 91.261
# Prediction BPM 90.49857470126233
# Win start,end: 18000, 19000
# Ground Truth BPM: 91.65
# Prediction BPM 121.83954111760215
# Win start,end: 18250, 19250
# Ground Truth BPM: 92.308
# Prediction BPM 95.8785663422426
# Win start,end: 18500, 19500
# Ground Truth BPM: 91.931
# Prediction BPM 92.48801202268294
# Win start,end: 18750, 19750
# Ground Truth BPM: 90.066
# Prediction BPM 93.65125336694932
# Win start,end: 19000, 20000
# Ground Truth BPM: 89.189
# Prediction BPM 87.83089616432329
# Win start,end: 19250, 20250
# Ground Truth BPM: 88.997
# Prediction BPM 92.16347793921886
# Win start,end: 19500, 20500
# Ground Truth BPM: 89.606
# Prediction BPM 104.21510487522826
# Win start,end: 19750, 20750
# Ground Truth BPM: 89.869
# ...
# Ground Truth BPM: 163.7555
# Prediction BPM 155.7395791949973
# Win start,end: 27000, 28000
# Ground Truth BPM: 164.0625
# Prediction BPM 152.73241197523652
# Win start,end: 27250, 28250
# Ground Truth BPM: 164.9215
# Prediction BPM 161.29326975668482
# Win start,end: 27500, 28500
# Ground Truth BPM: 165.7895
# Prediction BPM 161.73717587846508
# Win start,end: 27750, 28750
# Ground Truth BPM: 167.0201
# Prediction BPM 163.43261440855076
# Win start,end: 28000, 29000
# Ground Truth BPM: 167.9104
# Prediction BPM 166.99838816277227
# Win start,end: 28250, 29250
# Ground Truth BPM: 168.2692
# Prediction BPM 159.2555348353992
# Win start,end: 28500, 29500
# Ground Truth BPM: 168.3673
# Prediction BPM 136.30516214540503
# Win start,end: 28750, 29750
# Ground Truth BPM: 168.2692
# Prediction BPM 155.22749785430878
# Win start,end: 29000, 30000
# Ground Truth BPM: 168.5393
# Prediction BPM 162.544595682925
# Win start,end: 29250, 30250
# Ground Truth BPM: 168.7117
# Prediction BPM 161.55736000748442
# Win start,end: 29500, 30500
# Ground Truth BPM: 169.5371
# Prediction BPM 161.69814749404804
# Win start,end: 29750, 30750
# Ground Truth BPM: 169.0574
# Prediction BPM 167.48156482323378
# Win start,end: 30000, 31000
# Ground Truth BPM: 169.1094
# Prediction BPM 161.1333922732106
# Win start,end: 30250, 31250
# Ground Truth BPM: 169.3548
# Prediction BPM 161.50805571047889
# Win start,end: 30500, 31500
# Ground Truth BPM: 169.5786
# Prediction BPM 157.51280289067074
# Win start,end: 30750, 31750
# Ground Truth BPM: 170.1031
# Prediction BPM 155.65733126002863
# Win start,end: 31000, 32000
# Ground Truth BPM: 170.4545
# Prediction BPM 161.69814749404804
# Win start,end: 31250, 32250
# Ground Truth BPM: 170.6308
# Prediction BPM 162.33155762783747
# Win start,end: 31500, 32500
# Ground Truth BPM: 169.9029
# Prediction BPM 162.80081075039266
# Win start,end: 31750, 32750
# Ground Truth BPM: 170.6392
# Prediction BPM 159.18744802014166
# Win start,end: 32000, 33000
# Ground Truth BPM: 170.2786
# Prediction BPM 152.88627062437098
# Win start,end: 32250, 33250
# Ground Truth BPM: 170.1031
# Prediction BPM 174.64771913571406
# Win start,end: 32500, 33500
# Ground Truth BPM: 170.2703
# Prediction BPM 166.76839745324844
# Win start,end: 32750, 33750
# Ground Truth BPM: 170.4545
# Prediction BPM 171.51275528751964
# Win start,end: 33000, 34000
# Ground Truth BPM: 170.6308
# Prediction BPM 147.70642459412852
# Win start,end: 33250, 34250
# Ground Truth BPM: 170.2703
# Prediction BPM 163.5388803621031
# Win start,end: 33500, 34500
# Ground Truth BPM: 170.4545
# Prediction BPM 162.544595682925
# Win start,end: 33750, 34750
# Ground Truth BPM: 169.7531
# Prediction BPM 164.144269210787
# Win start,end: 34000, 35000
# Ground Truth BPM: 169.6429
# Prediction BPM 146.83279655184842
# Win start,end: 34250, 35250
# Ground Truth BPM: 170.1031
# Prediction BPM 159.05065730825217
# Win start,end: 34500, 35500
# Ground Truth BPM: 169.9279
# Prediction BPM 149.06564641763086
# Win start,end: 34750, 35750
# Ground Truth BPM: 169.3548
# Prediction BPM 159.4474502428043
# Win start,end: 35000, 36000
# Ground Truth BPM: 168.0244
# Prediction BPM 166.54244735347257
# Win start,end: 35250, 36250
# Ground Truth BPM: 166.1392
# Prediction BPM 142.51814034026964
# Win start,end: 35500, 36500
# Ground Truth BPM: 164.956
# Prediction BPM 135.74340617865332
# Win start,end: 0, 1000
# Ground Truth BPM: 97.9325
# Prediction BPM 106.06701341791228
# Win start,end: 250, 1250
# Ground Truth BPM: 99.1189
# Prediction BPM 100.1336010203803
# Win start,end: 500, 1500
# Ground Truth BPM: 99.5575
# Prediction BPM 95.65645737029726
# Win start,end: 750, 1750
# Ground Truth BPM: 100.2227
# Prediction BPM 106.3010176983538
# Win start,end: 1000, 2000
# Ground Truth BPM: 98.5844
# Prediction BPM 116.9790049826458
# Win start,end: 1250, 2250
# Ground Truth BPM: 96.831
# Prediction BPM 92.30917411139224
# Win start,end: 1500, 2500
# Ground Truth BPM: 97.7199
# Prediction BPM 95.46221734394607
# Win start,end: 1750, 2750
# Ground Truth BPM: 99.1862
# Prediction BPM 108.65190892234843
# Win start,end: 2000, 3000
# Ground Truth BPM: 102.6226
# Prediction BPM 103.77708899127146
# Win start,end: 2250, 3250
# Ground Truth BPM: 104.2781
# Prediction BPM 110.96613365035554
# Win start,end: 2500, 3500
# Ground Truth BPM: 103.7234
# Prediction BPM 103.4783935142637
# Win start,end: 2750, 3750
# Ground Truth BPM: 103.6866
# Prediction BPM 100.51124665656874
# Win start,end: 3000, 4000
# Ground Truth BPM: 101.1411
# Prediction BPM 104.00518779133162
# Win start,end: 3250, 4250
# Ground Truth BPM: 100.3344
# Prediction BPM 102.19152046083317
# Win start,end: 3500, 4500
# Ground Truth BPM: 101.6684
# Prediction BPM 101.26079736783593
# Win start,end: 3750, 4750
# Ground Truth BPM: 101.2461
# Prediction BPM 102.08361792674248
# Win start,end: 4000, 5000
# Ground Truth BPM: 100.1112
# Prediction BPM 85.7365594279224
# Win start,end: 4250, 5250
# Ground Truth BPM: 98.4683
# Prediction BPM 94.94166728889651
# Win start,end: 4500, 5500
# Ground Truth BPM: 97.9325
# Prediction BPM 91.90026342657153
# Win start,end: 4750, 5750
# Ground Truth BPM: 100.4464
# Prediction BPM 106.54388510049881
# Win start,end: 5000, 6000
# Ground Truth BPM: 104.8387
# Prediction BPM 111.63009289686326
# Win start,end: 5250, 6250
# Ground Truth BPM: 108.3591
# Prediction BPM 116.79559371613257
# Win start,end: 5500, 6500
# Ground Truth BPM: 110.9937
# Prediction BPM 111.2810825633263
# Win start,end: 5750, 6750
# Ground Truth BPM: 113.8664
# Prediction BPM 143.15410358620804
# Win start,end: 6000, 7000
# Ground Truth BPM: 117.5549
# Prediction BPM 131.53480079619655
# Win start,end: 6250, 7250
# Ground Truth BPM: 120.064
# Prediction BPM 114.95756694155489
# Win start,end: 6500, 7500
# Ground Truth BPM: 119.936
# Prediction BPM 119.60105771143137
# Win start,end: 6750, 7750
# Ground Truth BPM: 120.4497
# Prediction BPM 131.3113096056037
# Win start,end: 7000, 8000
# Ground Truth BPM: 119.936
# Prediction BPM 128.74507876097005
# Win start,end: 7250, 8250
# Ground Truth BPM: 120.4497
# Prediction BPM 145.10714874145265
# Win start,end: 7500, 8500
# Ground Truth BPM: 121.8852
# Prediction BPM 117.9394353380986
# Win start,end: 7750, 8750
# Ground Truth BPM: 123.8987
# Prediction BPM 147.70642459412852
# Win start,end: 8000, 9000
# Ground Truth BPM: 125.8389
# Prediction BPM 122.03124359303516
# Win start,end: 8250, 9250
# Ground Truth BPM: 126.5823
# Prediction BPM 147.68170723788324
# Win start,end: 8500, 9500
# Ground Truth BPM: 126.4489
# Prediction BPM 126.31844783055868
# Win start,end: 8750, 9750
# Ground Truth BPM: 125.7862
# Prediction BPM 129.8265923256259
# Win start,end: 9000, 10000
# Ground Truth BPM: 125.523
# Prediction BPM 128.74507876097005
# Win start,end: 9250, 10250
# Ground Truth BPM: 125.6983
# Prediction BPM 145.10714874145265
# Win start,end: 9500, 10500
# Ground Truth BPM: 126.0504
# Prediction BPM 133.1680803665553
# Win start,end: 9750, 10750
# Ground Truth BPM: 126.8499
# Prediction BPM 133.56568069033986
# Win start,end: 10000, 11000
# Ground Truth BPM: 127.6596
# Prediction BPM 128.1298780043333
# Win start,end: 10250, 11250
# Ground Truth BPM: 128.9181
# Prediction BPM 133.1680803665553
# Win start,end: 10500, 11500
# Ground Truth BPM: 130.1518
# Prediction BPM 144.18108393885936
# Win start,end: 10750, 11750
# Ground Truth BPM: 131.291
# Prediction BPM 118.14054475848141
# Win start,end: 11000, 12000
# Ground Truth BPM: 132.3988
# Prediction BPM 155.88553170586417
# Win start,end: 11250, 12250
# Ground Truth BPM: 133.3333
# Prediction BPM 136.6662625175019
# Win start,end: 11500, 12500
# Ground Truth BPM: 134.3519
# Prediction BPM 130.96817949931778
# Win start,end: 11750, 12750
# Ground Truth BPM: 135.3503
# Prediction BPM 155.22749785430878
# Win start,end: 12000, 13000
# Ground Truth BPM: 137.3922
# Prediction BPM 129.33380379462307
# Win start,end: 12250, 13250
# Ground Truth BPM: 139.607
# Prediction BPM 146.04278957393797
# Win start,end: 12500, 13500
# Ground Truth BPM: 142.4581
# Prediction BPM 144.39271753571657
# Win start,end: 12750, 13750
# Ground Truth BPM: 144.8498
# Prediction BPM 144.82069760261444
# Win start,end: 13000, 14000
# Ground Truth BPM: 146.9072
# Prediction BPM 143.33463664402598
# Win start,end: 13250, 14250
# Ground Truth BPM: 149.2147
# Prediction BPM 155.4362858422638
# Win start,end: 13500, 14500
# Ground Truth BPM: 150.7937
# Prediction BPM 161.1333922732106
# Win start,end: 13750, 14750
# Ground Truth BPM: 151.5957
# Prediction BPM 151.13416379912377
# Win start,end: 14000, 15000
# Ground Truth BPM: 152.4064
# Prediction BPM 132.596141715717
# Win start,end: 14250, 15250
# Ground Truth BPM: 153.0612
# Prediction BPM 148.83707953090268
# Win start,end: 14500, 15500
# Ground Truth BPM: 154.321
# Prediction BPM 155.4362858422638
# Win start,end: 14750, 15750
# Ground Truth BPM: 155.6017
# Prediction BPM 119.05826859102521
# Win start,end: 15000, 16000
# Ground Truth BPM: 156.5762
# Prediction BPM 150.3311615231983
# Win start,end: 15250, 16250
# Ground Truth BPM: 157.7287
# Prediction BPM 147.70642459412852
# Win start,end: 15500, 16500
# Ground Truth BPM: 158.7302
# Prediction BPM 153.87919269064253
# Win start,end: 15750, 16750
# Ground Truth BPM: 159.7444
# Prediction BPM 155.4362858422638
# Win start,end: 16000, 17000
# Ground Truth BPM: 160.4278
# Prediction BPM 156.34607702962728
# Win start,end: 16250, 17250
# Ground Truth BPM: 161.0429
# Prediction BPM 155.17404402590407
# Win start,end: 16500, 17500
# Ground Truth BPM: 161.6379
# Prediction BPM 161.1333922732106
# Win start,end: 16750, 17750
# Ground Truth BPM: 161.3924
# Prediction BPM 155.4362858422638
# Win start,end: 17000, 18000
# Ground Truth BPM: 162.3377
# Prediction BPM 155.4362858422638
# Win start,end: 17250, 18250
# Ground Truth BPM: 163.0435
# Prediction BPM 147.3201200733995
# Win start,end: 17500, 18500
# Ground Truth BPM: 163.2124
# Prediction BPM 163.5388803621031
# Win start,end: 17750, 18750
# Ground Truth BPM: 163.3987
# Prediction BPM 150.0915097928478
# Win start,end: 18000, 19000
# Ground Truth BPM: 163.3817
# Prediction BPM 155.4362858422638
# Win start,end: 18250, 19250
# Ground Truth BPM: 161.987
# Prediction BPM 157.05162887175547
# Win start,end: 18500, 19500
# Ground Truth BPM: 161.2078
# Prediction BPM 161.1333922732106
# Win start,end: 18750, 19750
# Ground Truth BPM: 160.473
# Prediction BPM 147.70642459412852
# Win start,end: 19000, 20000
# Ground Truth BPM: 159.9147
# Prediction BPM 144.18108393885936
# Win start,end: 19250, 20250
# Ground Truth BPM: 159.7363
# Prediction BPM 147.02015997231013
# Win start,end: 19500, 20500
# Ground Truth BPM: 159.7444
# Prediction BPM 149.9309323573266
# Win start,end: 19750, 20750
# Ground Truth BPM: 159.2357
# Prediction BPM 158.79483919444453
# Win start,end: 20000, 21000
# Ground Truth BPM: 158.8629
# Prediction BPM 144.51352394188635
# Win start,end: 20250, 21250
# Ground Truth BPM: 158.7302
# Prediction BPM 152.65534532945236
# Win start,end: 20500, 21500
# Ground Truth BPM: 158.5624
# Prediction BPM 145.3037753800799
# Win start,end: 20750, 21750
# Ground Truth BPM: 158.0611
# Prediction BPM 152.15244596812394
# Win start,end: 21000, 22000
# Ground Truth BPM: 157.0681
# Prediction BPM 152.4935235823881
# Win start,end: 21250, 22250
# Ground Truth BPM: 156.0874
# Prediction BPM 149.52276077602434
# Win start,end: 21500, 22500
# Ground Truth BPM: 154.9587
# Prediction BPM 149.23502025443463
# Win start,end: 21750, 22750
# Ground Truth BPM: 153.8462
# Prediction BPM 149.52276077602434
# Win start,end: 22000, 23000
# Ground Truth BPM: 152.897
# Prediction BPM 135.60524515099678
# Win start,end: 22250, 23250
# Ground Truth BPM: 152.0811
# Prediction BPM 139.22888673709838
# Win start,end: 22500, 23500
# Ground Truth BPM: 150.9534
# Prediction BPM 128.0438522016472
# Win start,end: 22750, 23750
# Ground Truth BPM: 150.1581
# Prediction BPM 136.4553895498835
# Win start,end: 23000, 24000
# Ground Truth BPM: 148.4375
# Prediction BPM 143.30198210247235
# Win start,end: 23250, 24250
# Ground Truth BPM: 147.2107
# Prediction BPM 144.70317477892075
# Win start,end: 23500, 24500
# Ground Truth BPM: 146.4208
# Prediction BPM 140.8432077659047
# Win start,end: 23750, 24750
# Ground Truth BPM: 145.9459
# Prediction BPM 145.53762083373442
# Win start,end: 24000, 25000
# Ground Truth BPM: 145.808
# Prediction BPM 144.33006370124593
# Win start,end: 24250, 25250
# Ground Truth BPM: 145.9459
# Prediction BPM 145.10714874145265
# Win start,end: 24500, 25500
# Ground Truth BPM: 145.7883
# Prediction BPM 140.98898265489524
# Win start,end: 24750, 25750
# Ground Truth BPM: 145.8547
# Prediction BPM 144.71850577730632
# Win start,end: 25000, 26000
# Ground Truth BPM: 146.1538
# Prediction BPM 145.48262685781992
# Win start,end: 25250, 26250
# Ground Truth BPM: 145.7055
# Prediction BPM 145.3037753800799
# Win start,end: 25500, 26500
# Ground Truth BPM: 147.363
# Prediction BPM 143.30198210247235
# Win start,end: 25750, 26750
# Ground Truth BPM: 145.0054
# Prediction BPM 144.18108393885936
# Win start,end: 26000, 27000
# Ground Truth BPM: 143.77
# Prediction BPM 130.93106949994407
# Win start,end: 26250, 27250
# Ground Truth BPM: 142.4051
# Prediction BPM 155.7395791949973
# Win start,end: 26500, 27500
# Ground Truth BPM: 141.2134
# Prediction BPM 144.07786050120492
# Win start,end: 26750, 27750
# Ground Truth BPM: 140.1869
# Prediction BPM 142.671173522468
# Win start,end: 27000, 28000
# Ground Truth BPM: 139.9561
# Prediction BPM 146.15607448486577
# Win start,end: 27250, 28250
# Ground Truth BPM: 140.264
# Prediction BPM 155.4362858422638
# Win start,end: 27500, 28500
# Ground Truth BPM: 141.3613
# Prediction BPM 145.54411848131107
# Win start,end: 27750, 28750
# Ground Truth BPM: 142.5554
# Prediction BPM 140.8790374690331
# Win start,end: 28000, 29000
# Ground Truth BPM: 144.385
# Prediction BPM 125.62030048852425
# Win start,end: 28250, 29250
# Ground Truth BPM: 147.363
# Prediction BPM 151.61619443100028
# Win start,end: 28500, 29500
# Ground Truth BPM: 148.9028
# Prediction BPM 145.58494116442577
# Win start,end: 28750, 29750
# Ground Truth BPM: 151.1135
# Prediction BPM 144.82069760261444
# Win start,end: 29000, 30000
# Ground Truth BPM: 153.4091
# Prediction BPM 149.79314539423802
# Win start,end: 29250, 30250
# Ground Truth BPM: 155.2795
# Prediction BPM 156.64904325737407
# Win start,end: 29500, 30500
# Ground Truth BPM: 156.9038
# Prediction BPM 144.3557343390991
# Win start,end: 29750, 30750
# Ground Truth BPM: 158.7302
# Prediction BPM 157.77742839640632
# Win start,end: 30000, 31000
# Ground Truth BPM: 160.2238
# Prediction BPM 151.61619443100028
# Win start,end: 30250, 31250
# Ground Truth BPM: 161.2903
# Prediction BPM 156.34607702962728
# Win start,end: 30500, 31500
# Ground Truth BPM: 162.7066
# Prediction BPM 160.93094918030963
# Win start,end: 30750, 31750
# Ground Truth BPM: 163.2124
# Prediction BPM 163.66075057587375
# Win start,end: 31000, 32000
# Ground Truth BPM: 164.0625
# Prediction BPM 154.6219307120471
# Win start,end: 31250, 32250
# Ground Truth BPM: 164.0625
# Prediction BPM 152.8831320248997
# Win start,end: 31500, 32500
# Ground Truth BPM: 164.749
# Prediction BPM 160.93094918030963
# Win start,end: 31750, 32750
# Ground Truth BPM: 165.4412
# Prediction BPM 151.61619443100028
# Win start,end: 32000, 33000
# Ground Truth BPM: 165.7895
# Prediction BPM 162.40857519553606
# Win start,end: 32250, 33250
# Ground Truth BPM: 166.4905
# Prediction BPM 150.3311615231983
# Win start,end: 32500, 33500
# Ground Truth BPM: 167.5532
# Prediction BPM 156.6669895455445
# Win start,end: 32750, 33750
# Ground Truth BPM: 168.3673
# Prediction BPM 151.2741981520231
# Win start,end: 33000, 34000
# Ground Truth BPM: 169.7198
# Prediction BPM 155.4362858422638
# Win start,end: 33250, 34250
# Ground Truth BPM: 170.2786
# Prediction BPM 155.4362858422638
# Win start,end: 33500, 34500
# Ground Truth BPM: 169.9279
# Prediction BPM 154.89503128844353
# Win start,end: 33750, 34750
# Ground Truth BPM: 168.6296
# Prediction BPM 143.17348512117428
# Win start,end: 34000, 35000
# Ground Truth BPM: 167.3428
# Prediction BPM 162.5848327982139
# Win start,end: 34250, 35250
# Ground Truth BPM: 165.7895
# Prediction BPM 157.8597906405995
# Win start,end: 34500, 35500
# Ground Truth BPM: 163.7214
# Prediction BPM 150.95379460972623
# Win start,end: 34750, 35750
# Ground Truth BPM: 162.5387
# Prediction BPM 161.03732825141952
# Win start,end: 35000, 36000
# Ground Truth BPM: 160.4278
# Prediction BPM 130.36051875297494
# Win start,end: 35250, 36250
# Ground Truth BPM: 159.0668
# Prediction BPM 156.91012210838338
# Win start,end: 35500, 36500
# Ground Truth BPM: 157.3977
# Prediction BPM 110.07530631605408
# Win start,end: 35750, 36750
# Ground Truth BPM: 156.25
# Prediction BPM 152.11995647855986
# Win start,end: 36000, 37000
# Ground Truth BPM: 155.4404
# Prediction BPM 150.6728936888044
# Win start,end: 36250, 37250
# Ground Truth BPM: 154.0041
# Prediction BPM 153.39380034093915

# %%
sth
# Out:
# 8.8514712875202122

# %% [markdown]
# -----
# ### Project Write-up
#
# Answer the following prompts to demonstrate understanding of the algorithm you wrote for this specific context.
#
# > - **Code Description** - Include details so someone unfamiliar with your project will know how to run your code and use your algorithm.
# > - **Data Description** - Describe the dataset that was used to train and test the algorithm. Include its short-comings and what data would be required to build a more complete dataset.
# > - **Algorithhm Description** will include the following:
# >   - how the algorithm works
# >   - the specific aspects of the physiology that it takes advantage of
# >   - a describtion of the algorithm outputs
# >   - caveats on algorithm outputs
# >   - common failure modes
# > - **Algorithm Performance** - Detail how performance was computed (eg. using cross-validation or train-test split) and what metrics were optimized for. Include error metrics that would be relevant to users of your algorithm. Caveat your performance numbers by acknowledging how generalizable they may or may not be on different datasets.

# %% [markdown]
# ### Code Description:
#
# #### Programming Language:
# - Python >=3.6
#
# #### Dependencies:
# - numpy
# - scipy
# - matplotlib
#
#
# ####  Run the algorithm:
# From the main directory:
#
# - Step 1 - Define the path for the DATA AND REF folders which should be set up inside the function LoadTroikaDataset() in the variable `data_dir`.
#
# - Step 2 - Run the function:
# ```python
# result = Evaluate()
# ```
# Optionally:
# - In the function create_features, we can set up two parameters to `True` for plotting the frequencies and peaks. `plot_frequency_ppg`,  `plot_frequency_acc`
#
# ```python
# feature, freqs_initial,  fft_ppg  = create_features(indice, ppg_window, accx_window, accy_window, accz_window,
#                             min_freq_val, max_freq_val, Fs, verbose = verbose,
#                             plot_frequency_ppg = True, plot_frequency_acc = True)
# ```
#
# ### Data Description:
# The data contains signals recorded from  wrist devices when the subjects were doing intensive exercise, the signals are contaminated by intentional/unintentional movements of the arm.
#
# Each file contains the following signals:
# - 3-axis accelerometer signal
# - PPG signal
#
#
#
#
#
# ### Algorithm Description:
#
# #### How the algorithm works:
#
# - Load data: Load to memory the PPG signal and accelerometer data from 12 subjects.
#
#
# - Create Features:
#     - Band Pass Filtering: Attenues certain frequencies in a specific range. In this case we apply a range between 40 - 240 BPM. It removes some motion artifacts.
#
#     - Signal Decomposition: It descompose our signal using Fast Fourier transformation. Then the components related to noise and interference are removed. The final signal can be reconstructed base on the components that were not removed.
#
#     - Find peaks: Detect the peaks in our signal that was bandpassed.
#
# - Train Model: the dataset is splitted assigning 20% of the data for test and 80% for training.
#
# - Test Model: The model is tested by running the algorithm over the whole dataset.
#
# - Calculate confidence: The the confidence is calculate base on the sum of the frequency spectrum near the pulse rate estimate and dividing it by the sum of the entire spectrum. This output is produce every two seconds.
#
# - Agregate Error metrics: Computes the MAE at 90% availability.
#
#
# ![Troika Flow](img/flow_motion.png)
#
# #### The specific aspects of the physiology that it takes advantage of
# - Wrist Type PPG signal: The ppg signal can be use to measure the Heart rate of a subject, this signal is collected from a non invasive method where the signal measure the volumetric variation of the blood circulation.
#
# - Accelerometer signal:  Measures the accelaration forces in different axis, for our project we need to differentiate between unintentional movements thaht generates noise in ur signal to predict the next value of the heart rate.
#
# #### Description of the algorithm outputs
#
# #### Caveats on algorithm outputs
# The dataset was build base on the data collected of 12 subjects performing intensive physical exercise (PPG, Accelerometer signal), whose activity is similar. This similarity could lead the algorithm to perform better than it really is if it tested in other subjects whose activity differ from the data that was used.
#
# #### Common failure modes
# - The PPG signal is vulnerable to motion artifacts such as the device not being well-attach to the wrist of the subject. It might add aditional noise to the signal.
# - The algorithm was developed to perform well under normal conditions, the algorithm has not been tested under water, high altitude or other extreme condition.
#
#
# ####  Algorithm Performance:
#
# - The algorithm selected was RandomForest because it get the lowest measures of error in comparison to Ridge Regression and Support Vector Machine which exceeds MAE of 15
#
# Random Forest Parameters:
# - max_depth = 15
# - estimators = 350
#
# Train test split
# - test_percentage = 0.2
# - train_percetange = 0.8
#
#
# - The performance was given by using the Mean absolute Error.
#
# $
# MAE = \frac{1}{n} * \sum_{i {=} 1}^{n} \left | x_{i} - x\right |
# $
#
# - The model performs obtaining a `MAE` of **9.01** over the entire dataset comparing a 2 seconds ground truth.

# %% [markdown]
# -----
# ### Next Steps
# You will now go to **Test Your Algorithm** to apply a unit test to confirm that your algorithm met the success criteria.
